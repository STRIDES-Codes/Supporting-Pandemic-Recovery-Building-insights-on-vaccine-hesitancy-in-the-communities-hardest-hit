# %%
import csv

# %%
import tweepy as tw
import pandas as pd

# %%
auth = tw.OAuthHandler(API_key, API_secret)
auth.set_access_token(access_token, access_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_words = "#idonotconsent -filter:retweets"
date_since = "2020-12-01"

# %%
for i in range(100):
    print(f"Starting search: #{i}")
    tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000)
    
    with open("../data/twitter_search.csv", 'a', newline='') as csvFile:
        csvWriter = csv.writer(csvFile)
        for tweet in tweets:
            tweets_encoded = tweet.text.encode('utf-8')
            tweets_decoded = tweets_encoded.decode('utf-8')
            if tweet.id not in ids:
                csvWriter.writerow([tweet.id, tweets_decoded, tweet.created_at, tweet.geo, tweet.place.name if tweet.place else None, tweet.coordinates, tweet._json["user"]["location"]])

    twitter_df = pd.read_csv("../data/twitter_search.csv", 
                         names=["id", "tweet", "date", "drop0", "drop1", "drop2", "location"])
    
    print(f"New data count: {len(twitter_df)}")
    ids = twitter_df.id.to_list()
# Out:
# Starting search: #0
# New data count: 8237
# Starting search: #1
# New data count: 8237
# Starting search: #2
# New data count: 8237
# Starting search: #3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-190-e791361cdeed> in <module>
#       8     with open("../data/twitter_search.csv", 'a', newline='') as csvFile:
#       9         csvWriter = csv.writer(csvFile)
# ---> 10         for tweet in tweets:
#      11             tweets_encoded = tweet.text.encode('utf-8')
#      12             tweets_decoded = tweets_encoded.decode('utf-8')
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/cursor.py in __next__(self)
#      49
#      50     def __next__(self):
# ---> 51         return self.next()
#      52
#      53     def next(self):
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/cursor.py in next(self)
#     241         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     242             # Reached end of current page, get the next page...
# --> 243             self.current_page = self.page_iterator.next()
#     244             while len(self.current_page) == 0:
#     245                 self.current_page = self.page_iterator.next()
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/cursor.py in next(self)
#     130
#     131         if self.index >= len(self.results) - 1:
# --> 132             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     133
#     134             if hasattr(self.method, '__self__'):
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# ~/anaconda3/lib/python3.8/site-packages/tweepy/binder.py in execute(self)
#     182                 # Execute request
#     183                 try:
# --> 184                     resp = self.session.request(self.method,
#     185                                                 full_url,
#     186                                                 data=self.post_data,
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
twitter_df.head()
# Out:
#                     id                                              tweet  \
# 0  1407417288106680322  @MLAStefanson @mingoertzen @BrianPallister tha...
# 1  1407417265994223622  @akelvinlab But Pfizer Fact Sheet for Health C...
# 2  1407417186948243458  Vaccination centers for 18-44 age group: \n1. ...
# 3  1407417182577889281  @peterktodd „WHO's Strategic Advisory Group of...
# 4  1407417156032155651  @Truthseeker1985 This turd also ignores Expert...
#
#                   date  drop0 drop1  drop2          location
# 0  2021-06-22 19:16:44    NaN   NaN    NaN               YWG
# 1  2021-06-22 19:16:39    NaN   NaN    NaN               NaN
# 2  2021-06-22 19:16:20    NaN   NaN    NaN  Hyderabad, India
# 3  2021-06-22 19:16:19    NaN   NaN    NaN           Cologne
# 4  2021-06-22 19:16:13    NaN   NaN    NaN               NaN

# %%
df = twitter_df.drop_duplicates()

# %%
len(df)
# Out:
# 5436

# %%
df.head()
# Out:
#                     id                                              tweet  \
# 0  1407417288106680322  @MLAStefanson @mingoertzen @BrianPallister tha...
# 1  1407417265994223622  @akelvinlab But Pfizer Fact Sheet for Health C...
# 2  1407417186948243458  Vaccination centers for 18-44 age group: \n1. ...
# 3  1407417182577889281  @peterktodd „WHO's Strategic Advisory Group of...
# 4  1407417156032155651  @Truthseeker1985 This turd also ignores Expert...
#
#                   date  drop0 drop1  drop2          location
# 0  2021-06-22 19:16:44    NaN   NaN    NaN               YWG
# 1  2021-06-22 19:16:39    NaN   NaN    NaN               NaN
# 2  2021-06-22 19:16:20    NaN   NaN    NaN  Hyderabad, India
# 3  2021-06-22 19:16:19    NaN   NaN    NaN           Cologne
# 4  2021-06-22 19:16:13    NaN   NaN    NaN               NaN

# %%
df.drop(["drop0", "drop1", "drop2"], axis=1, inplace=True)
# Out:
# /Users/enceladosaurus/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.drop(["date", "location", "id"], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                tweet
# 0  @MLAStefanson @mingoertzen @BrianPallister tha...
# 1  @akelvinlab But Pfizer Fact Sheet for Health C...
# 2  Vaccination centers for 18-44 age group: \n1. ...
# 3  @peterktodd „WHO's Strategic Advisory Group of...
# 4  @Truthseeker1985 This turd also ignores Expert...

# %%
df.to_csv("../data/cleaned_twitter.csv")

# %%
import nltk
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/enceladosaurus/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/enceladosaurus/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/enceladosaurus/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
twitter_training = pd.read_csv("../data/twitter_training.csv", names=["positivity", "tweetid", "date", "query", "user", "tweet"])

# %%
twitter_training.head()
# Out:
#    positivity                                              tweet
# 0           0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1           0  is upset that he can't update his Facebook by ...
# 2           0  @Kenichan I dived many times for the ball. Man...
# 3           0    my whole body feels itchy and like its on fire
# 4           0  @nationwideclass no, it's not behaving at all....

# %%
#twitter_training.drop(["tweetid", "date", "query", "user"], axis=1, inplace=True)

# %%
twitter_training.positivity = twitter_training.positivity.replace(4, 1)

# %%
negative = twitter_training[twitter_training.positivity == 0]

# %%
positive = twitter_training[twitter_training.positivity == 1]

# %%
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.tag import pos_tag
from nltk.stem import WordNetLemmatizer

# %%
negative_tweets = negative.tweet.to_list()
positive_tweets = positive.tweet.to_list()

# %%
tweet_tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)

# %%
lemmatizer = WordNetLemmatizer()

# %%
def lemmatize(token_list: list) -> list:
    lemmatized_tokens = []
    for token, tag in pos_tag(token_list):
        if tag.startswith('VB'):
            pos = 'v'
        elif tag.startswith('NN'):
            pos = 'n'
        else:
            pos = 'a'
        lemmatized_tokens.append(lemmatizer.lemmatize(token, pos))
    
    return lemmatized_tokens

# %%
def clean_data(token_list: list, stop_words: list) -> list:
    trim_characters = ['!', '.', ',', '*', '&', '%', '$', '?', '""', ":", ";", "(", ")", "-", "/"]
    remove_characters = ['@', '#', '//']
    cleaned_tokens = []
    
    for token in token_list:
        for character in trim_characters:
            if character in token:
                token = token.strip(character)
        for character in remove_characters:
            if character in token:
                token = ''
                
        if len(token) > 1 and token.lower() not in stop_words:
            cleaned_tokens.append(token)
    
    return cleaned_tokens

# %%
tweets[0]
# Out:
# '@MLAStefanson @mingoertzen @BrianPallister thank you very much for allowing my child to be eligible for a vaccinati… https://t.co/M06ldOZ4sS'

# %%
stop_words = stopwords.words('english')

# %%
test = tweet_tokenizer.tokenize(tweets[0])

# %%
test = lemmatize(test)

# %%
test = clean_data(test, stop_words)

# %%
test
# Out:
# ['awww', "that's", 'bummer', 'shoulda', 'got', 'david', 'carr', 'third', 'day']

# %%
negative_data  = [tweet_tokenizer.tokenize(x) for x in negative_tweets]

# %%
positive_data  = [tweet_tokenizer.tokenize(x) for x in positive_tweets]

# %%
def prepare_data(all_tokens: list, stop_words: list):
    cleaned_data = []
    for token_list in all_tokens:
        cleaned_tokens = clean_data(token_list, stop_words)
        lemmatized_tokens = lemmatize(cleaned_tokens)
        cleaned_data.append(cleaned_tokens)
    
    return cleaned_data

# %%
cleaned_negative = prepare_data(negative_data, stop_words)

# %%
cleaned_positive = prepare_data(positive_data, stop_words)

# %%
cleaned_positive[0]
# Out:
# ['love', 'guys', 'best']

# %%
def convert_to_dict(all_tokens: list) -> dict:
    for token_list in all_tokens:
        yield dict([token, True] for token in token_list)

# %%
def prepare_data_for_model(positive_tokens: list, negative_tokens: list) -> list:
    positive_tweets = [(positive_dict, "Positive") for positive_dict in convert_to_dict(positive_tokens)]
    negative_tweets = [(negative_dict, "Negative") for negative_dict in convert_to_dict(negative_tokens)]
    
    return positive_tweets + negative_tweets

# %%
all_tweets = prepare_data_for_model(cleaned_positive, cleaned_negative)

# %%
from nltk import classify
from nltk import NaiveBayesClassifier

# %%
import random

# %%
random.shuffle(all_tweets)

# %%
train = all_tweets[:round(len(all_tweets) * 0.2)]
test = all_tweets[round(len(all_tweets) * 0.2):]

# %%
nbc = NaiveBayesClassifier.train(train)

# %%
classify.accuracy(nbc, test)
# Out:
# 0.756590625

# %%
nbc.show_most_informative_features(10)
# Out:
# Most Informative Features
#                  mcmahon = True           Negati : Positi =     48.4 : 1.0
#                   farrah = True           Negati : Positi =     43.0 : 1.0
#                   boohoo = True           Negati : Positi =     40.4 : 1.0
#                carradine = True           Negati : Positi =     40.4 : 1.0
#                  saddest = True           Negati : Positi =     35.8 : 1.0
#               devastated = True           Negati : Positi =     31.0 : 1.0
#                    strep = True           Negati : Positi =     31.0 : 1.0
#                      447 = True           Negati : Positi =     26.4 : 1.0
#                  sadface = True           Negati : Positi =     25.7 : 1.0
#                     sadd = True           Negati : Positi =     25.0 : 1.0

# %%
tweets = df.tweet.to_list()

# %%
vax_data = [tweet_tokenizer.tokenize(x) for x in tweets]

# %%
vax_tweets = prepare_data(vax_data, stop_words)

# %%
nbc.classify(dict([token, True] for token in vax_tweets[0]))
# Out:
# 'Negative'

# %%
negatives = []
positives = []
for tweet in vax_tweets:
    if nbc.classify(dict([token, True] for token in tweet)) == 'Negative':
        negatives.append(tweet)
    else:
        positives.append(tweet)

# %%
negatives
# Out:
# [['thank', 'much', 'allowing', 'child', 'eligible', 'vaccinati', '…'],
#  ['pfizer',
#   'fact',
#   'sheet',
#   'health',
#   'care',
#   'providers',
#   'clearly',
#   'states',
#   '"',
#   'data',
#   'available',
#   'int',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'g',
#   'narayanamma',
#   'inst',
#   'tech',
#   'shaikpet',
#   'pin',
#   '50008',
#   'vaccine',
#   'covaxin',
#   '…'],
#  ['turd',
#   'also',
#   'ignores',
#   'expert',
#   'vaccinologist',
#   'geert',
#   'vanden',
#   'bossche',
#   'warns',
#   'ongoing',
#   'global',
#   'mass',
#   'xperiv',
#   '…'],
#  ['celebrated',
#   'giving',
#   '20,000',
#   'th',
#   'dose',
#   'pfizer',
#   'covid',
#   'vaccine',
#   'today',
#   'lsu',
#   'health',
#   'new',
#   'orleans',
#   'vaccine',
#   'poin',
#   '…'],
#  ['reported',
#   'cdc',
#   'analysis',
#   'adult',
#   'covid',
#   '19',
#   '“',
#   'vaccination',
#   'rates',
#   'age',
#   'may',
#   '22',
#   '”',
#   'found',
#   '“',
#   '8',
#   '…'],
#  ['philippine',
#   'president',
#   'threatened',
#   'order',
#   'arrest',
#   'filipinos',
#   'refuse',
#   'covid',
#   '19',
#   'vaccination',
#   'told',
#   '…'],
#  ['interactive',
#   'map',
#   'shows',
#   'first',
#   'dose',
#   'vaccination',
#   'rates',
#   'every',
#   'ontario',
#   'region',
#   '|',
#   '…'],
#  ['covid',
#   'vaccination',
#   'rate',
#   'dropped',
#   'sharply',
#   'past',
#   'month',
#   'even',
#   'shots',
#   'become',
#   'available',
#   'puttin',
#   '…'],
#  ['post',
#   'vaccination',
#   'symptoms',
#   'clotting',
#   'deaths',
#   'pfizer',
#   'vaccine',
#   'significant',
#   'ho',
#   '…'],
#  ['two-thirds',
#   'snohomish',
#   'county',
#   'residents',
#   'ages',
#   '16',
#   'plus',
#   'least',
#   'begun',
#   'vaccination',
#   'covid',
#   '1',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'khilwath',
#   'play',
#   'ground',
#   'charminar',
#   'charminar',
#   'pin',
#   '500065',
#   'vaccine',
#   'cova',
#   '…'],
#  ['u', 'hit', 'july', '4', 'vaccination', 'goal', 'white', 'house', 'says'],
#  ['u', 'hit', 'july', '4', 'vaccination', 'goal', 'white', 'house', 'says'],
#  ['add',
#   'passport',
#   'option',
#   'second',
#   'dose',
#   '28',
#   'days',
#   'international',
#   'travel',
#   'state',
#   '…'],
#  ['real',
#   'good',
#   'cause',
#   'vaccination',
#   'generally',
#   'tarnished',
#   'vaccine',
#   'experts',
#   'wading',
#   'much',
#   '…'],
#  ['u', 'hit', 'july', '4', 'vaccination', 'goal', 'white', 'house', 'says'],
#  ['u', 'hit', 'july', '4', 'vaccination', 'goal', 'white', 'house', 'says'],
#  ['eligible',
#   '2nd',
#   'dose',
#   '‘',
#   'astrazeneca',
#   'oxford',
#   '’',
#   'vaccinated',
#   '…'],
#  ['semi-finals', 'fans', 'attending', 'games', 'wembley', 'need', '…'],
#  ['president',
#   'biden',
#   'set',
#   'goal',
#   '70',
#   'adult',
#   'americans',
#   'least',
#   'one',
#   'covid',
#   '19',
#   'vaccine',
#   'shot',
#   '160',
#   'mil',
#   '…'],
#  ['still', 'politicians', 'telling', 'people', 'va', '…'],
#  ['adding',
#   'reported',
#   'grass',
#   'inside',
#   'newcastle',
#   '’',
#   'new',
#   'pop-up',
#   'vaccine',
#   'tent',
#   '18s',
#   '…'],
#  ['vancouver',
#   'coastal',
#   'health',
#   'opened',
#   'limited',
#   'number',
#   'drop-in',
#   'spots',
#   'vaccination',
#   'sites',
#   'vancouver',
#   'north',
#   'v',
#   '…'],
#  ['vaccine',
#   'appointments',
#   'available',
#   'walgreens',
#   'duane',
#   'reade',
#   'pfizer',
#   '5716',
#   'avenue',
#   'u',
#   'brooklyn',
#   'ny',
#   '11234',
#   '8',
#   '00',
#   '925',
#   '…'],
#  ['vaccination',
#   'numbers',
#   'wrong',
#   '2',
#   'dose',
#   'vaccine',
#   'sisonke',
#   'trial',
#   'numbers',
#   'tr',
#   '…'],
#  ['atlantic',
#   'health',
#   'least',
#   'nj',
#   'providing',
#   'virtual',
#   'vaccine',
#   'card',
#   'displayed',
#   'c',
#   '…'],
#  ['agree',
#   'messaging',
#   'needs',
#   'much',
#   'nuanced',
#   'people',
#   'understand',
#   'need',
#   'stricter',
#   'continued',
#   '…'],
#  ['saw',
#   'tiktok',
#   'abt',
#   'guy',
#   'less',
#   'pimples',
#   'bcs',
#   'vaccine',
#   "where's",
#   'nearest',
#   'vaccination',
#   'site'],
#  ['took',
#   'dad',
#   'vaccination',
#   'people',
#   'shown',
#   'vaccines',
#   'available',
#   'health',
#   '…'],
#  ['genuine', 'centers', 'track', 'vaccination', 'status', 'cowin', 'app', '…'],
#  ['“',
#   'fda',
#   'requires',
#   'healthcare',
#   'providers',
#   'report',
#   'death',
#   'covid',
#   '19',
#   'vac',
#   '…'],
#  ['philippines',
#   '’',
#   'duterte',
#   'threatens',
#   'jail',
#   'refuse',
#   'covid',
#   '19',
#   'vaccine',
#   '…'],
#  ['india', 'tries', 'jump', 'start', 'sluggish', 'vaccination', 'effort'],
#  ["i'm",
#   'favor',
#   'forced',
#   'vaccination',
#   'theoretically',
#   'work',
#   'done',
#   'america',
#   '…'],
#  ['mississippi',
#   'home',
#   'larger',
#   'percentage',
#   'black',
#   'people',
#   'state',
#   'initially',
#   'saw',
#   'stark',
#   'vaccination',
#   '…'],
#  ['today',
#   'nova',
#   'scotia',
#   'celebrated',
#   'administering',
#   '800,000',
#   'doses',
#   'covid',
#   '19',
#   'vaccine',
#   'premier',
#   'celebrated',
#   'milestone',
#   '…'],
#  ['heads',
#   'vaccination',
#   'pop-up',
#   'held',
#   '5',
#   '8',
#   'p',
#   'tonight',
#   'queer',
#   'bar',
#   'capitol',
#   'hill',
#   '1518',
#   '11th',
#   'ave',
#   '…'],
#  ['pediatricians',
#   'across',
#   'us',
#   'regularly',
#   'conversations',
#   'vaccine',
#   'families',
#   '…'],
#  ['come',
#   'ycph',
#   'vaccination',
#   'station',
#   'moderna',
#   'vaccine',
#   'clinic',
#   'wednesday',
#   'june',
#   '23',
#   '3',
#   'p',
#   '–',
#   '3:30',
#   'p',
#   'p',
#   '…'],
#  ['shingles',
#   'years',
#   'getting',
#   'older',
#   'vaccination',
#   'horrible',
#   'yet',
#   'considered',
#   '…'],
#  ['think',
#   'tank',
#   'said',
#   'asian',
#   'countries',
#   'could',
#   'achieve',
#   'herd',
#   'immunity',
#   'next',
#   'year',
#   'except',
#   'philip',
#   '…'],
#  ['“',
#   'united',
#   'states',
#   'miss',
#   'president',
#   'biden',
#   '’',
#   'original',
#   'goal',
#   'getting',
#   'least',
#   'one',
#   'dose',
#   'coronavirus',
#   'vaccine',
#   '…'],
#  ['u', 'rate', 'slowed', '|', '|', '|', '|', '|', '…'],
#  ['oha',
#   'wants',
#   'collect',
#   'data',
#   'long-term',
#   'care',
#   'facilities',
#   'oregon',
#   'make',
#   'sure',
#   'staff',
#   'residents',
#   'meetin',
#   '…'],
#  ['possible',
#   'link',
#   'vaccines',
#   'heart',
#   'inflammation',
#   'bears',
#   'close',
#   'monitoring',
#   'experts',
#   'say',
#   '…'],
#  ['maharashtra',
#   'restarts',
#   'free',
#   'vaccination',
#   '18-30',
#   'age',
#   'group',
#   'report'],
#  ['ended',
#   'getting',
#   '2nd',
#   'dose',
#   'vaccine',
#   'event',
#   'past',
#   'weekend',
#   'look',
#   'ou',
#   '…'],
#  ['many',
#   'visa',
#   'holder',
#   'first',
#   'shot',
#   'sinopharm',
#   'vaccine',
#   'dubai',
#   'came',
#   'india',
#   'unable',
#   'take',
#   'ther',
#   '…'],
#  ['【',
#   'bot',
#   'crs',
#   '2',
#   'vaccination',
#   '】',
#   'mother',
#   'suffers',
#   '20',
#   'weeks',
#   'infect',
#   'fetus',
#   'mr',
#   'vaccine',
#   'recommended',
#   'twice',
#   'global',
#   '45',
#   'iu',
#   'ml'],
#  ['biden',
#   'admin',
#   'admits',
#   'reach',
#   'july',
#   '4',
#   'vaccination',
#   'goal',
#   'cdc',
#   'studies',
#   'explain',
#   'slowdown',
#   'latest',
#   'covid',
#   '19',
#   'updates',
#   '…'],
#  ['u45',
#   'hyderabad',
#   'vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'sultan',
#   'ul',
#   'ulum',
#   'society',
#   'shaikpet',
#   'pin',
#   '500033',
#   'vaccine',
#   '…'],
#  ['6/22',
#   '21',
#   'incentives',
#   'increase',
#   'vaccination',
#   'rate',
#   'good',
#   'advertising'],
#  ['full',
#   'polio',
#   'vaccination',
#   'provides',
#   'lifelong',
#   '100',
#   'immunity',
#   'tetanus',
#   'vac',
#   '…'],
#  ['’',
#   'sorry',
#   'would',
#   'never',
#   'vaccinate',
#   'teenager',
#   'experimental',
#   'vaccine',
#   'long',
#   'term',
#   'affects',
#   '…'],
#  ['ontario',
#   'met',
#   'vaccination',
#   'thresholds',
#   'required',
#   'enter',
#   '3rd',
#   'final',
#   'step',
#   'economic',
#   'reopening',
#   'weeks',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'sana',
#   'garden',
#   'function',
#   'hall',
#   'asif',
#   'nagar',
#   'pin',
#   '50002',
#   'vaccine',
#   'covishie',
#   '…'],
#  ['global',
#   'ceo',
#   'says',
#   'refused',
#   'federal',
#   'money',
#   'vaccine',
#   'r',
#   'remain',
#   'independent',
#   'fast',
#   'decisio',
#   '…'],
#  ['bangal',
#   'bottom',
#   'vaccination',
#   'instead',
#   'spreading',
#   'filth',
#   'please',
#   'focus',
#   'duty',
#   'wil',
#   '…'],
#  ['point',
#   'need',
#   'transition',
#   'vaccination',
#   'effort',
#   'family',
#   'physicians',
#   'pharmacists',
#   'public',
#   '…'],
#  ['ready',
#   'change',
#   'scene',
#   'make',
#   'appointment',
#   'get',
#   'covid',
#   '19',
#   'vaccine',
#   'find',
#   'local',
#   'vaccination',
#   'site',
#   'make',
#   '…'],
#  ['administration',
#   'plans',
#   'say',
#   'likely',
#   'fall',
#   'short',
#   'fourth',
#   'july',
#   'goal',
#   '…'],
#  ['possible',
#   'link',
#   'vaccines',
#   'heart',
#   'inflammation',
#   'bears',
#   'close',
#   'monitoring',
#   'experts',
#   'say',
#   '…'],
#  ["we've",
#   'covered',
#   'low',
#   'vaccine',
#   'rates',
#   'among',
#   'staff',
#   'new',
#   "york's",
#   'congregate',
#   'settings',
#   'prisons',
#   'homeless',
#   'shelters',
#   '…'],
#  ['fans',
#   'attending',
#   'games',
#   'wembley',
#   'need',
#   'follow',
#   'number',
#   'strict',
#   'entry',
#   'requi',
#   '…'],
#  ['worth',
#   'risk',
#   'children',
#   'vulnerable',
#   'risk',
#   'reward',
#   'ratio',
#   'vaccine',
#   '…'],
#  ['record',
#   '🎯',
#   '🏹',
#   'numbers',
#   'today',
#   'show',
#   'achievable',
#   'vaccine',
#   'administration',
#   'done',
#   'efficient',
#   'mann',
#   '…'],
#  ['global',
#   'vaccination',
#   'covid',
#   '19',
#   'remains',
#   'major',
#   'challenge',
#   'worldwide',
#   'due',
#   '…'],
#  ['riddle',
#   'something',
#   'huge',
#   'benefit',
#   'practically',
#   'risk',
#   'answered',
#   'covid',
#   'vaccine',
#   'correc',
#   '…'],
#  ['help',
#   'keep',
#   'covid',
#   '19',
#   'vaccination',
#   'appointments',
#   'open',
#   'others',
#   'cancelling',
#   'bookings',
#   'longer',
#   'need'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'marredpally',
#   'multi',
#   'funct',
#   'hall',
#   'marredpally',
#   'pin',
#   '500017',
#   'vaccine',
#   'co',
#   '…'],
#  ['biden',
#   'administration',
#   'says',
#   'fall',
#   'short',
#   'fourth',
#   'july',
#   'vaccination',
#   'goal'],
#  ['vaccine', 'vaccination'],
#  ['always',
#   'thought',
#   'reasons',
#   'resistance',
#   'smallpox',
#   'vaccination',
#   'idiotic',
#   'crystal',
#   'clear',
#   'n',
#   '…'],
#  ['yet',
#   'vaccinated',
#   'please',
#   'visit',
#   'find',
#   'vaccination',
#   'location',
#   '…'],
#  ['india', 'tries', 'jump', 'start', 'sluggish', 'vaccination', 'effort'],
#  ['walk-in',
#   'vaccination',
#   'allowed',
#   '16',
#   'govt',
#   'sites',
#   'south',
#   'delhi',
#   'available',
#   '…'],
#  ['health',
#   'workers',
#   'come',
#   'homes',
#   'chicagoan',
#   '12',
#   'older',
#   'get',
#   'vaccinated',
#   'shots',
#   'free',
#   '…'],
#  ['rand', 'paul', 'mixing', 'vaccine', 'message', 'covid', 'survivors'],
#  ['wow',
#   '🙌',
#   '🏼',
#   '’',
#   'approaching',
#   '400,000',
#   'doses',
#   'vaccine',
#   'administered',
#   '’',
#   'received',
#   '…'],
#  ['israel',
#   'used',
#   'pfizer',
#   'vaccine',
#   'second-highest',
#   'vaccination',
#   'rate',
#   'world',
#   'seychelles',
#   'new',
#   'daily',
#   'confirmed',
#   '…'],
#  ['according',
#   '2.65',
#   'billion',
#   'covid',
#   '19',
#   'vaccine',
#   'doses',
#   'admini',
#   '…'],
#  ['race',
#   'get',
#   'vaccinated',
#   'gotten',
#   'vaccination',
#   'yet',
#   'time',
#   'call',
#   'detro',
#   '…'],
#  ['polio', 'vaccination', 'started', 'eradication', 'polio', "'", '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'nasr',
#   'girls',
#   'school',
#   'khairatabad',
#   'khairtabad',
#   'pin',
#   '500016',
#   'vaccine',
#   'covi',
#   '…'],
#  ['rand',
#   'paul',
#   'mixing',
#   'vaccine',
#   'message',
#   'covid',
#   'survivors',
#   'kaiser',
#   'health',
#   'news'],
#  ['vro',
#   'second',
#   'dose',
#   '45',
#   '+',
#   'directly',
#   'go',
#   'vaccination',
#   'centre',
#   'need',
#   '…'],
#  ['fil',
#   'got',
#   'first',
#   'dose',
#   'yesterday',
#   'little',
#   'sister',
#   "who's",
#   'vaccine',
#   'hesitant',
#   'getting',
#   'first',
#   'dose',
#   'friday',
#   '…'],
#  ['illegal',
#   'hospital',
#   'illegal',
#   'covid',
#   'centre',
#   'hospital',
#   'fire',
#   'wrong',
#   'vaccination',
#   'duplicate',
#   'vaccine',
#   'busted',
#   'also',
#   'yahi',
#   'hai',
#   'khani',
#   'yha',
#   'ki'],
#  ['still', 'covishield', 'vaccine', 'recognised', 'oxfor', '…'],
#  ['need',
#   'keep',
#   'momentum',
#   'going',
#   'find',
#   'absurd',
#   'people',
#   'compare',
#   'vaccination',
#   'coun',
#   '…'],
#  ['see', 'wonder', 'discussion', 'gov', 'oea', 'whe', '…'],
#  ['takeaway',
#   'governments',
#   'really',
#   'serious',
#   'getting',
#   'vaccination',
#   'rates',
#   "they'd",
#   '…'],
#  ['hi',
#   '，',
#   '23days',
#   'since',
#   'got',
#   'first',
#   'vaccination',
#   'walk',
#   'take',
#   'second',
#   'vaccine'],
#  ['sickening',
#   "'",
#   'thank',
#   'modiji',
#   "'",
#   'vaccination',
#   "what's",
#   'contribution',
#   'except',
#   'disastrous',
#   'vaccine',
#   'policy'],
#  ['kansas',
#   'city',
#   'chiefs',
#   'tight',
#   'end',
#   'travis',
#   "kelce's",
#   'calling',
#   'people',
#   'get',
#   'vaccine',
#   'previous',
#   'hesitancy',
#   '…'],
#  ['“',
#   'smallpox',
#   'vaccination',
#   'provides',
#   'full',
#   'immunity',
#   '3',
#   '5',
#   'years',
#   'decreasing',
#   'im',
#   '…'],
#  ['vaccine',
#   'appointments',
#   'available',
#   'walgreens',
#   'duane',
#   'reade',
#   'moderna',
#   '1612',
#   'westchester',
#   'avenue',
#   'bronx',
#   'ny',
#   '10472',
#   '8',
#   '…'],
#  ["yrmc's",
#   'state-supported',
#   'vaccine',
#   'clinic',
#   'longer',
#   'administer',
#   'covid',
#   '19',
#   'vaccines',
#   '6pm',
#   'sat',
#   'june',
#   '26',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'govt',
#   'school',
#   'musheerabad',
#   'musheerabad',
#   'pin',
#   '500020',
#   'vaccine',
#   'covaxin',
#   '…'],
#  ['ek',
#   'din',
#   '84',
#   'lakh',
#   'vaccination',
#   'world',
#   'record',
#   '500',
#   'days',
#   'v',
#   'pakistan',
#   'aaj',
#   'tak',
#   '60',
#   'lakh',
#   'vaccine',
#   'v',
#   'nh',
#   '…'],
#  ['today',
#   'philippines',
#   'president',
#   'threatened',
#   'jail',
#   'citizens',
#   'reluc',
#   '…'],
#  ['please',
#   'get',
#   'moron',
#   'wh',
#   'oh',
#   'thanks',
#   'president',
#   'trump',
#   'made',
#   'vaccine',
#   'possible',
#   'biden',
#   'cough',
#   '…'],
#  ['false',
#   'truth',
#   'great',
#   'news',
#   'receive',
#   'vaccine',
#   'still',
#   'donate',
#   'blood',
#   'platelet',
#   '…'],
#  ['arwady',
#   'us',
#   'unique',
#   'almost',
#   'entirely',
#   'unique',
#   'enough',
#   'vaccine',
#   'widely',
#   'available',
#   'ages',
#   'c',
#   '…'],
#  ['half',
#   'people',
#   'want',
#   'get',
#   'vaccinated',
#   'though',
#   'cbs',
#   'news',
#   'u',
#   'expected',
#   'hit',
#   "biden's",
#   '70',
#   'covid',
#   '…'],
#  ['1',
#   'nurse',
#   'first',
#   'vaccination',
#   'said',
#   'something',
#   'quite',
#   'pertinent',
#   'vaccine',
#   'stops',
#   'de',
#   '…'],
#  ['false',
#   'truth',
#   '"',
#   'great',
#   'news',
#   'receive',
#   'vaccine',
#   'still',
#   'donate',
#   'blood',
#   '…'],
#  ['nhs',
#   'sending',
#   'texts',
#   'people',
#   'invite',
#   'book',
#   'covid',
#   '19',
#   'vaccine',
#   'appointment',
#   'may',
#   'come',
#   '…'],
#  ['vaccines', 'use', 'uk', 'protect', 'coronavirus', 'delay', 'getting', '…'],
#  ['india', 'tries', 'jump', 'start', 'sluggish', 'vaccination', 'effort'],
#  ['vaccination',
#   'clinic',
#   'resource',
#   'fair',
#   'happening',
#   'saturday',
#   'june',
#   '26th',
#   '10am',
#   '2pm',
#   'jurupa',
#   'valley',
#   'attendees',
#   '…'],
#  ['western',
#   'michigan',
#   'university',
#   'giving',
#   'cash',
#   'incentives',
#   '60',
#   'students',
#   'show',
#   'proof',
#   'vaccination',
#   '…'],
#  ['hard', 'vaccination', 'conversations'],
#  ['stage',
#   'managed',
#   'vaccine',
#   'drive',
#   'got',
#   'exposed',
#   'today',
#   '17',
#   'lakhs',
#   'jabs',
#   'vaccination',
#   '21.6',
#   '2021',
#   'mp',
#   'today',
#   '…'],
#  ["here's",
#   'weekly',
#   'update',
#   'covid',
#   'vaccine',
#   'june',
#   '11',
#   '5,993',
#   'deaths',
#   '6,156',
#   'life-threatening',
#   'adve',
#   '…'],
#  ['covid',
#   '19',
#   'live',
#   'updates',
#   'quebec',
#   'set',
#   'add',
#   'moderna',
#   'walk-in',
#   'clinics',
#   'open',
#   '2nd',
#   'dose',
#   'appointments'],
#  ['weekend',
#   'reported',
#   'regional',
#   'efforts',
#   'get',
#   'kids',
#   'vaccinated',
#   'c',
#   "'",
#   'youth',
#   'vaccination',
#   'rates',
#   'lagging',
#   '…'],
#  ['30',
#   'years',
#   'research',
#   'yes',
#   'small',
#   'scale',
#   'trials',
#   'people',
#   'alrea',
#   '…'],
#  ['become', 'immortal', 'vaccination', 'vaccine', '100', 'efficacy'],
#  ['need',
#   'ride',
#   'get',
#   'covid',
#   '19',
#   'vaccination',
#   '📞',
#   'dial',
#   '211',
#   'schedule',
#   'free',
#   'transportation',
#   'provided',
#   '…'],
#  ['covid',
#   '19',
#   'situation',
#   'palestine',
#   'concerning',
#   'locally',
#   'globally',
#   'crowded',
#   'conditions',
#   'degraded',
#   'healthcar',
#   '…'],
#  ['vaccination',
#   'immunization',
#   'sheep',
#   'either',
#   'vaccine',
#   'ineffective',
#   '…'],
#  ['india', 'inoculated', 'record', '8.6', 'million', 'doses', 'covid', '19'],
#  ['presstitutes',
#   'none',
#   'government',
#   'done',
#   'record',
#   'vaccination',
#   'today',
#   '28',
#   'cr',
#   'done',
#   '28cr',
#   'vaccine',
#   'av',
#   '…'],
#  ['basically',
#   'means',
#   'avoid',
#   'southeast',
#   'right',
#   'becuz',
#   '’',
#   'matter',
#   'time',
#   '…'],
#  ['6-22',
#   '21',
#   'biden',
#   'administration',
#   'admits',
#   'reach',
#   'july',
#   '4',
#   'vaccination',
#   'goal',
#   'cdc',
#   'studies',
#   'explain',
#   'vaccination',
#   'slowdow',
#   '…'],
#  ['ask',
#   'daktari',
#   '"',
#   'got',
#   'sputnik',
#   'vaccine',
#   'get',
#   'second',
#   'dose',
#   'govt',
#   'keeping',
#   'thi',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'vinay',
#   'nagar',
#   'community',
#   'hall',
#   'saidabad',
#   'pin',
#   '500039',
#   'vaccine',
#   'covaxin',
#   '…'],
#  ['get',
#   'ready',
#   'lot',
#   'people',
#   'refuse',
#   'get',
#   'vaccine',
#   'dog',
#   'president',
#   'white',
#   'house',
#   'says',
#   'us',
#   'fa',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'venkateswara',
#   'cln',
#   'himayathnagar',
#   'amberpet',
#   'pin',
#   '500029',
#   'vaccine',
#   'covax',
#   '…'],
#  ['please',
#   '’',
#   'parrot',
#   'rahul',
#   'gandhi',
#   'speaks',
#   'concerned',
#   'enough',
#   'set',
#   'vaccination',
#   'centre',
#   '…'],
#  ['second',
#   'dose',
#   'hopes',
#   'kenya',
#   'receives',
#   '358,700',
#   'doses',
#   'astrazeneca',
#   'vaccine',
#   'denmark',
#   'gov',
#   '’',
#   'says',
#   'health',
#   'workers',
#   '…'],
#  ['even',
#   'understand',
#   'difference',
#   'vaccine',
#   'immunization',
#   'drops',
#   'polio',
#   'immunization',
#   'star',
#   '…'],
#  ['members',
#   'families',
#   'need',
#   'assistance',
#   'obtaining',
#   'vaccination',
#   'information',
#   'cdc',
#   'guidelines',
#   'please',
#   '…'],
#  ['covid',
#   'vaccination',
#   'rate',
#   'dropped',
#   'sharply',
#   'past',
#   'month',
#   'even',
#   'shots',
#   'become',
#   'available',
#   'puttin',
#   '…'],
#  ['threat',
#   'get',
#   'vaccine',
#   'philippine',
#   'president',
#   'threatened',
#   'order',
#   'arrest',
#   'filipinos',
#   'refuse',
#   'covi',
#   '…'],
#  ['“',
#   'blaming',
#   'low',
#   'covid',
#   '19',
#   'vaccination',
#   'rates',
#   'vaccine',
#   'hesitancy',
#   'analysts',
#   'health-care',
#   'providers',
#   'effectively',
#   '…'],
#  ['hard', 'vaccination', 'conversations', 'new', 'york', 'times'],
#  ['developing',
#   'covid',
#   '19',
#   'vaccine',
#   'experimental',
#   'population',
#   'generally',
#   'ages',
#   '…'],
#  ['vaccine',
#   'administration',
#   'state',
#   'slow',
#   'might',
#   'point',
#   'state',
#   'g',
#   '…'],
#  ['vaccine', 'sent', 'countries', 'need', 'us', '…'],
#  ['|',
#   '"',
#   'mega',
#   'vaccination',
#   '1',
#   'day',
#   'match',
#   'image-building',
#   'cost',
#   'lives',
#   '…'],
#  ['rcog',
#   'rcm',
#   'advice',
#   'covid',
#   'vaccination',
#   'pregnancy',
#   'consultant',
#   'obstetrician',
#   'wome',
#   '…'],
#  ['covid',
#   'vaccination',
#   'pop-up',
#   'clinic',
#   'take',
#   'place',
#   'inside',
#   'silver',
#   'springs',
#   'primary',
#   'academy',
#   'stalybridge',
#   'saturday',
#   '26',
#   'ju',
#   '…'],
#  ['got',
#   'vaccine',
#   'walgreens',
#   'give',
#   'gift',
#   'card',
#   'get',
#   'one',
#   'store'],
#  ['…'],
#  ['link',
#   'show',
#   'vaccination',
#   'progress',
#   'state',
#   'p',
#   'south',
#   'gonna',
#   'kill',
#   'us',
#   '…'],
#  ['🚨',
#   'huge',
#   'red',
#   'flag',
#   'desantis',
#   '🚨',
#   'governor',
#   'florida',
#   'banned',
#   'vaccine',
#   'passports',
#   'covid',
#   '19',
#   'secretly',
#   'slipped',
#   '…'],
#  ['covid',
#   '19',
#   'india',
#   'administers',
#   '52',
#   'lakh',
#   'vaccine',
#   'doses',
#   'today',
#   '|',
#   'india',
#   'news',
#   '–',
#   'times',
#   'india'],
#  ['big',
#   'problem',
#   'israel',
#   'though',
#   'vaccination',
#   'status',
#   'vaccine',
#   '100',
#   'effective'],
#  ['respected',
#   'sir',
#   '5',
#   'days',
#   'remain',
#   '2nd',
#   'dose',
#   'covexin.still',
#   'unable',
#   'book',
#   'slot',
#   'cowin',
#   'vaccinat',
#   '…'],
#  ['literally',
#   'cannot',
#   'make',
#   'statement',
#   'dont',
#   'seem',
#   'understand',
#   'biology',
#   'wor',
#   '…'],
#  ['vaccination',
#   'status',
#   'voluntary',
#   'get',
#   'vaccine',
#   'assigned',
#   'racial',
#   'category',
#   'prej',
#   '…'],
#  ['heading',
#   'shop',
#   'vaccination',
#   'clinics',
#   'extended',
#   'chelsea',
#   'fall',
#   'river',
#   'lawrence',
#   'lynn',
#   'revere',
#   '…'],
#  ['📣',
#   'participating',
#   'covid',
#   '19',
#   'college',
#   'vaccine',
#   'challenge',
#   'keep',
#   'safe',
#   'committing',
#   'ac',
#   '…'],
#  ['vaccine',
#   'map',
#   'countries',
#   'around',
#   'world',
#   '2',
#   'billion',
#   'doses',
#   'administered',
#   'wo',
#   '…'],
#  ['first',
#   'effective',
#   'polio',
#   'vaccine',
#   'developed',
#   '1952',
#   'india',
#   'gave',
#   '17',
#   'cr',
#   'dose',
#   '60',
#   'years',
#   'india',
#   'gave',
#   'record',
#   '8',
#   'million',
#   '…'],
#  ['mcph',
#   'covid',
#   '19',
#   'vaccination',
#   'clinic',
#   'open',
#   'today',
#   'troy',
#   'business',
#   'park',
#   'location',
#   '430p',
#   '630p',
#   '…'],
#  ['bro',
#   'actually',
#   'vaccine',
#   'extra',
#   'doses',
#   'vial',
#   'accounting',
#   'wastage',
#   '…'],
#  ['four', 'men', 'developed', 'guillain-barré', 'jab', 'cases', 'linked', '…'],
#  ['okay',
#   'also',
#   'say',
#   'something',
#   'millions',
#   'died',
#   'due',
#   'covid',
#   'migrant',
#   'labourers',
#   'people',
#   'died',
#   'bec',
#   '…'],
#  ["'",
#   "i'll",
#   'inject',
#   'vaccine',
#   'butt',
#   "'",
#   'philippines',
#   'president',
#   'threatens',
#   'arrest',
#   'refuse',
#   'vaccination'],
#  ["'",
#   "i'll",
#   'inject',
#   'vaccine',
#   'butt',
#   "'",
#   'philippines',
#   'president',
#   'threatens',
#   'arrest',
#   'refuse',
#   'vaccination'],
#  ['icymi',
#   'ontario',
#   'providing',
#   'accessible',
#   'rides',
#   'vaccination',
#   'sites',
#   'loved',
#   'ones',
#   'accessible',
#   'needs',
#   '…'],
#  ['uh', 'death', 'preventable', 'idea', '…'],
#  ['🚨',
#   'walk-ins',
#   'held',
#   'week',
#   '✅',
#   'due',
#   '2nd',
#   'dose',
#   'covid',
#   '19',
#   'vaccine',
#   '8',
#   'weeks',
#   'first',
#   '…'],
#  ['haha',
#   'six',
#   'months',
#   '’',
#   'already',
#   'making',
#   'excuses',
#   'vaccination',
#   'numbers',
#   '30',
#   'shots',
#   '…'],
#  ['hospital',
#   'taking',
#   'aadhar',
#   'xerox',
#   'time',
#   'giving',
#   'vaccine',
#   'sub-hospital',
#   '…'],
#  ['find',
#   'vaccine',
#   'location',
#   'get',
#   'ride',
#   'get',
#   'accurate',
#   'information',
#   'vaccination',
#   'process',
#   'free',
#   'clicking',
#   '…'],
#  ['comparing',
#   'polio',
#   'corona',
#   'vaccine',
#   'least',
#   'sense',
#   'vaccination',
#   'strategies',
#   '…'],
#  ['hospital',
#   'workers',
#   'celebrate',
#   'zero',
#   'covid',
#   '19',
#   'patients',
#   'year',
#   'fighting',
#   'front',
#   'lines',
#   '“',
#   'us',
#   'nurses',
#   'w',
#   '…'],
#  ['mf',
#   'pointed',
#   'vaccinated',
#   'must',
#   'exercise',
#   'ongoing',
#   'caution',
#   'observe',
#   'public',
#   'health',
#   'measures',
#   'indicated',
#   'tha',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'bharat',
#   'ground',
#   'mallepally',
#   'nampally',
#   'pin',
#   '500095',
#   'vaccine',
#   'covaxin',
#   'c',
#   '…'],
#  ['currently', '51candidates', '10', 'candidates', 'phase', '3', '…'],
#  ["we're", 'either', 'yes', '1', 'vaccination', 'card', 'includes', '…'],
#  ['wanna',
#   'know',
#   'vaccination',
#   'progress',
#   'baltimore',
#   'interested',
#   'vaccine',
#   'related',
#   'funding',
#   'opportunities',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'thallabasthi',
#   'community',
#   'hall',
#   'musheerabad',
#   'pin',
#   '500080',
#   'vaccine',
#   'covax',
#   '…'],
#  ['right',
#   'planning',
#   'appears',
#   'gone',
#   'pot',
#   "we've",
#   'got',
#   'vaccination',
#   'centres',
#   'popping',
#   'ever',
#   '…'],
#  ['aged',
#   '18',
#   'join',
#   'millions',
#   'get',
#   'covid',
#   '19',
#   'vaccine',
#   'hampton',
#   'wick',
#   'surgery',
#   'weekend',
#   '💉',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'govt.junior',
#   'college',
#   'kachiguda',
#   'amberpet',
#   'pin',
#   '500027',
#   'vaccine',
#   'covaxi',
#   '…'],
#  ['california',
#   '’',
#   'health',
#   'technology',
#   'departments',
#   'announced',
#   'launch',
#   'new',
#   'website',
#   'allows',
#   'residents',
#   'fetch',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'nasar',
#   'girls',
#   'school',
#   'khairatabad',
#   'khairtabad',
#   'pin',
#   '500082',
#   'vaccine',
#   'cov',
#   '…'],
#  ['wtf',
#   'got',
#   'mederna',
#   'moderna',
#   'pfizer',
#   'vaccination',
#   'site',
#   'wont',
#   'let',
#   'match',
#   '…'],
#  ['love',
#   'vaccination',
#   'diaries',
#   'may',
#   'get',
#   'vaccine',
#   'today',
#   '"',
#   'v',
#   'unlikely',
#   '"',
#   "i've",
#   'already',
#   'sitting',
#   'ar',
#   '…'],
#  ['aged',
#   '18',
#   'join',
#   'millions',
#   'get',
#   'covid',
#   '19',
#   'vaccine',
#   'hampton',
#   'wick',
#   'surgery',
#   'weekend',
#   '💉',
#   '…'],
#  ['saturday',
#   '26th',
#   'june',
#   'holding',
#   'drop',
#   'covid',
#   '19',
#   'vaccination',
#   'clinic',
#   '10am',
#   '1pm',
#   '3pm',
#   '6pm',
#   'cathedr',
#   '…'],
#  ['41',
#   'delta',
#   'variant',
#   'deaths',
#   'uk',
#   'people',
#   '2',
#   'weeks',
#   'post',
#   'vaccination',
#   'total',
#   'deaths',
#   'low',
#   '…'],
#  ['hard', 'vaccination', 'conversations'],
#  ['israeli',
#   'officials',
#   'said',
#   'today',
#   'people',
#   'vaccinated',
#   '2',
#   'shots',
#   'among',
#   'infecti',
#   '…'],
#  ['hlo',
#   'mandatory',
#   'take',
#   '2',
#   'nd',
#   'dose',
#   'vaccine',
#   '14',
#   'days',
#   'travel',
#   'travel',
#   '…'],
#  ['vaccination',
#   'update',
#   '70',
#   'americans',
#   '30',
#   'first',
#   'vaccine',
#   'shot'],
#  ['happening',
#   'officials',
#   'chicago',
#   'department',
#   'public',
#   'health',
#   'discuss',
#   'expansion',
#   'city',
#   '’',
#   'in-home',
#   'vacci',
#   '…'],
#  ['happening',
#   'officials',
#   'chicago',
#   'department',
#   'public',
#   'health',
#   'discuss',
#   'expansion',
#   'city',
#   '’',
#   'in-home',
#   'vacci',
#   '…'],
#  ['white',
#   'house',
#   'says',
#   'meeting',
#   'biden',
#   '’',
#   'vaccination',
#   'goal',
#   'less',
#   'important',
#   'pace',
#   'nation',
#   '’',
#   'reopening',
#   'wh',
#   '…'],
#  ['full',
#   'vaccination',
#   'single',
#   '2',
#   'doses',
#   'vaccine',
#   'vaccine',
#   'covid',
#   'confirmed',
#   'cause',
#   'death'],
#  ['true', 'really', 'want', 'get', 'chinese', 'vaccine', 'unfortunately', '…'],
#  ['covid',
#   'vaccine',
#   'passport',
#   'scam',
#   'email',
#   'purports',
#   'nhs',
#   'informs',
#   'apply',
#   '“',
#   'digital',
#   'coronavirus',
#   'passports',
#   '”',
#   '…'],
#  ['vaccines',
#   'philippine',
#   'president',
#   'threatened',
#   'order',
#   'arrest',
#   'filipinos',
#   'refuse',
#   'covid',
#   '19',
#   'vaccination',
#   '…'],
#  ['duterte', 'threatens', 'arrest', 'filipinos', 'refuse', 'vaccination'],
#  ['maharashtra',
#   'administers',
#   'record',
#   '5.52',
#   'lakh',
#   'covid',
#   '19',
#   'vaccine',
#   'doses',
#   'single',
#   'day',
#   '…'],
#  ['70',
#   'americans',
#   'age',
#   '30',
#   'older',
#   'received',
#   'least',
#   'one',
#   'dose',
#   'covid',
#   'vaccine',
#   'psaki',
#   'says',
#   'sho',
#   '…'],
#  ['today',
#   'received',
#   'first',
#   'dose',
#   'phizer',
#   'covid',
#   '19',
#   'vaccine',
#   'step',
#   'one',
#   'getting',
#   'back',
#   'normal',
#   '’',
#   'always',
#   'grate',
#   '…'],
#  ['vaccine', 'vaccination', 'starting', 'administration', 'terr', '…'],
#  ['south',
#   'bay',
#   'family',
#   'health',
#   'care',
#   'partnership',
#   'beach',
#   'cities',
#   'health',
#   'district',
#   'closing',
#   'vaccination',
#   '…'],
#  ['data',
#   'watchdog',
#   'says',
#   'lack',
#   'public',
#   'health',
#   'advice',
#   'requiring',
#   'businesses',
#   'collect',
#   'vaccination',
#   'data',
#   'means',
#   'may',
#   '…'],
#  ['u',
#   'expected',
#   'hit',
#   '70',
#   'covid',
#   'vaccination',
#   'goal',
#   'july',
#   '4',
#   '70',
#   'adults',
#   '30',
#   'older',
#   'received',
#   'le',
#   '…'],
#  ['country',
#   'world',
#   'much',
#   'hue',
#   'cry',
#   'raised',
#   'giving',
#   'vaccination',
#   'citizens.vacc',
#   '…'],
#  ['stop',
#   'mindless',
#   'never',
#   'ending',
#   'lies',
#   'drama',
#   'disgusting',
#   'gave',
#   '11',
#   'lakhs',
#   'vaccine',
#   'sto',
#   '…'],
#  ['propaganda',
#   'vaccination',
#   'publicity',
#   'even',
#   'begun',
#   'yet',
#   'wait',
#   'like',
#   'pm',
#   "kisan's",
#   'first',
#   '3',
#   'inst',
#   '…'],
#  ['expected',
#   'hit',
#   "biden's",
#   '70',
#   'covid',
#   'vaccination',
#   'goal',
#   'july',
#   '4',
#   '…'],
#  ['students',
#   'indiana',
#   'university',
#   'filed',
#   'federal',
#   'lawsuit',
#   'suing',
#   'school',
#   'covid',
#   '19',
#   'vaccination',
#   'requirement'],
#  ['hopefully',
#   'serious',
#   'vaccination',
#   'vaccine',
#   'deadly',
#   'many',
#   'people',
#   'died',
#   '…'],
#  ['happened',
#   'vaccine',
#   'kept',
#   'phenomenal',
#   'cold',
#   'temperatures',
#   'see',
#   'nothing',
#   'vaccination',
#   '…'],
#  ['➡',
#   '️',
#   "india's",
#   'covid',
#   '19',
#   'vaccination',
#   'coverage',
#   'crosses',
#   'landmark',
#   '29',
#   'cr',
#   '➡',
#   '️',
#   '2nd',
#   'day',
#   'new',
#   '…'],
#  ['🚨',
#   'walk-ins',
#   'held',
#   'week',
#   '✅',
#   'due',
#   '2nd',
#   'dose',
#   'covid',
#   '19',
#   'vaccine',
#   '8',
#   'weeks',
#   'first',
#   '…'],
#  ['🚨',
#   'walk-ins',
#   'held',
#   'week',
#   '✅',
#   'due',
#   '2nd',
#   'dose',
#   'covid',
#   '19',
#   'vaccine',
#   '8',
#   'weeks',
#   'first',
#   '…'],
#  ['sir',
#   'vaccination',
#   'large',
#   'scale',
#   'stop',
#   'losses',
#   'ray',
#   'hope',
#   'vaccine'],
#  ['received', 'covid', '19', 'vaccine', 'may', 'get', 'phone', 'call'],
#  ['vaccination', 'contraindicated', 'reaction', '…'],
#  ['former',
#   'head',
#   'fda',
#   'warned',
#   'delta',
#   'variant',
#   'covid',
#   '19',
#   'could',
#   'lead',
#   'surge',
#   'states',
#   'low',
#   'vaccinatio',
#   '…'],
#  ['“',
#   '’',
#   'santa',
#   'clara',
#   'county',
#   'bay',
#   'area',
#   'region',
#   'communities',
#   'took',
#   'covid',
#   'seriously',
#   'w',
#   '…'],
#  ['octagon',
#   'currently',
#   'offering',
#   '1st',
#   'doses',
#   'vaccine',
#   'pfizer',
#   '…'],
#  ['💉',
#   '|',
#   'residents',
#   'urged',
#   'get',
#   'covid',
#   '19',
#   'vaccine',
#   'vicarage',
#   'road'],
#  ['never',
#   'easier',
#   'get',
#   'vaccinated',
#   'london',
#   'locations',
#   'like',
#   'stamford',
#   'bridge',
#   'opening',
#   'va',
#   '…'],
#  ['u', 'take', 'vaccine', 'know', 'well', 'shortage', 'crisis', '…'],
#  ['vaccination',
#   'update',
#   '71.1',
#   'adult',
#   'new',
#   'yorkers',
#   'received',
#   'least',
#   'one',
#   'vaccine',
#   'dose',
#   '63.4',
#   'completed',
#   '…'],
#  ['top',
#   '3',
#   'states',
#   'vaccination',
#   'drive',
#   '"',
#   'illiterate',
#   'uneducated',
#   'gobar',
#   'bhakt',
#   '"',
#   'states',
#   'h',
#   '…'],
#  ['full',
#   'vaccination',
#   'mrna',
#   'vaccine',
#   'shows',
#   'good',
#   'protection',
#   'severe',
#   'illne',
#   '…'],
#  ['listening',
#   'msnbc',
#   'talk',
#   'covid',
#   'vaccine',
#   'disinformation',
#   'affecting',
#   'latino',
#   'community',
#   'vaccination',
#   'rates',
#   '…'],
#  ['vaccination', 'site', 'temperature', 'sensitive', 'vaccines', '…'],
#  ['everyone', '18', 'coronavirus', 'vaccine', 'find'],
#  ['4th',
#   'july',
#   'coming',
#   'president',
#   'biden',
#   '’',
#   'goal',
#   'getting',
#   '70',
#   'vaccination',
#   'rate',
#   'unlikel',
#   '…'],
#  ['u',
#   'narrowly',
#   'miss',
#   'president',
#   'biden',
#   '’',
#   'july',
#   '4',
#   'vaccination',
#   'goal',
#   'getting',
#   'least',
#   'one',
#   'dose',
#   'coronavirus',
#   'vaccine',
#   '…'],
#  ['vaccination',
#   'program',
#   'stepped',
#   'best',
#   'possible',
#   'situation',
#   'time',
#   'trump',
#   'vaccine',
#   '…'],
#  ['anyone',
#   'wants',
#   'vaccine',
#   'get',
#   'one',
#   'biden',
#   'would',
#   'require',
#   'people',
#   'take',
#   'vaccination',
#   'would',
#   'press',
#   'say'],
#  ['looks',
#   'like',
#   "they're",
#   'pushing',
#   'people',
#   'paid',
#   'vaccination',
#   'much',
#   'possible',
#   'please',
#   '…'],
#  ['die', '…'],
#  ['know', 'vaccination', 'going', 'cities', 'states', 'india', 'b', '…'],
#  ['covid', 'vaccine', 'map', 'countries', 'around', 'world', '<', '…'],
#  ['shepherd',
#   'man',
#   'receives',
#   'dose',
#   'covishield',
#   'coronavirus',
#   'vaccine',
#   'manufactured',
#   'serum',
#   'institute',
#   'india',
#   'durin',
#   '…'],
#  ['gps',
#   'vaccination',
#   'system',
#   'hospital',
#   'vaccine',
#   'systems',
#   'affected',
#   'could',
#   'supply',
#   'issue',
#   'maybe'],
#  ['goi',
#   'exerts',
#   'full',
#   'force',
#   'help',
#   'media',
#   'houses',
#   'ads',
#   'spendy',
#   'crores',
#   'rs',
#   'administer',
#   '85',
#   'lakhs',
#   'vac',
#   '…'],
#  ['loved',
#   'vaccination',
#   'record',
#   'dr',
#   'nk',
#   'arora',
#   'ntagi',
#   'says',
#   '22,00',
#   '00,000',
#   'vaccine',
#   'doses',
#   'available',
#   'b',
#   '…'],
#  ['learn',
#   'impact',
#   'pandemic',
#   'older',
#   'persons',
#   'connect',
#   'experts',
#   'adult',
#   'vaccination',
#   '…'],
#  ['received', 'covid', '19', 'vaccine', 'may', 'get', 'phone', 'call'],
#  ['day',
#   'record',
#   'vaccination',
#   'madhya',
#   'pradesh',
#   'state',
#   'population',
#   '8.2',
#   'crores',
#   'vaccinated',
#   'less',
#   '…'],
#  ['protect',
#   'loved',
#   'ones',
#   'covid',
#   '19',
#   'vaccine',
#   'get',
#   'durham',
#   'city',
#   'centre',
#   '📍',
#   'weekend',
#   '…'],
#  ['turkovac',
#   'becomes',
#   'first',
#   'locally-made',
#   'vaccine',
#   'start',
#   'phase',
#   'iii',
#   'trials',
#   'turkey',
#   'rapid',
#   'vaccination',
#   'ca',
#   '…'],
#  ['vaccine',
#   'medical',
#   'passport',
#   'required',
#   'places',
#   'already',
#   'rising',
#   'covid',
#   '19',
#   'infections',
#   'alarming',
#   'death',
#   'r',
#   '…'],
#  ['age',
#   'elmo',
#   'geared',
#   'towards',
#   '’',
#   'deciding',
#   'want',
#   'vaccine',
#   'ridiculous'],
#  ['low',
#   'vaccine',
#   'wastage',
#   'vaccination',
#   'speed',
#   'also',
#   'criteria',
#   'allocation',
#   'increase',
#   'vaccinatio',
#   '…'],
#  ['…'],
#  ['’',
#   'vaccine',
#   'first',
#   'shot',
#   'worst',
#   'disease',
#   'lot',
#   'worse',
#   'vaccin',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'mch',
#   'indoor',
#   'amberpet',
#   'amberpet',
#   'pin',
#   '500013',
#   'vaccine',
#   'covaxin',
#   'cost',
#   '…'],
#  ['𝗕𝗝𝗣',
#   '𝗖𝗟𝗔𝗜𝗠',
#   'states',
#   'failed',
#   'vaccination',
#   'procurement',
#   '𝗙𝗔𝗖𝗧',
#   'supreme',
#   'court',
#   'questioned',
#   'centre',
#   'dua',
#   '…'],
#  ['hence',
#   'prove',
#   'final',
#   'vaccination',
#   'yes',
#   'able',
#   'download',
#   'certificate',
#   '1st',
#   'dose',
#   '…'],
#  ['➡',
#   '️',
#   "india's",
#   'covid',
#   '19',
#   'vaccination',
#   'coverage',
#   'crosses',
#   'landmark',
#   '29',
#   'cr',
#   '➡',
#   '️',
#   '2nd',
#   'day',
#   'new',
#   '…'],
#  ['mcvs',
#   'tamilnadu',
#   'government',
#   'vaccination',
#   'list',
#   'babies',
#   'daughter',
#   '10',
#   'months',
#   'old',
#   'put',
#   'va',
#   '…'],
#  ['central', 'government', 'supplying', 'vaccines', 'government', '…'],
#  ['“',
#   'new',
#   'clinic',
#   'scheduled',
#   'open',
#   'wednesday',
#   'convention',
#   'centre',
#   'downtown',
#   'halifax',
#   'capable',
#   '…'],
#  ['vaccination', 'slow', 'u', 'ur', 'vaccin', '…'],
#  ['quebec', 'goes', 'green', 'monday', 'restrictions', 'lifting', 'legault'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'hindi',
#   'nagar',
#   'sports',
#   'comple',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'hindi',
#   'nagar',
#   'sports',
#   'complex',
#   'nampally',
#   'pin',
#   '500012',
#   'vaccine',
#   'covishiel',
#   '…'],
#  ['makes',
#   'lecture',
#   'paid',
#   'vaccination',
#   'wanted',
#   'pay',
#   'get',
#   'vaccinat',
#   '…'],
#  ['70',
#   'americans',
#   '30',
#   'older',
#   'received',
#   'covid',
#   '19',
#   'vaccine',
#   'white',
#   'house',
#   'says'],
#  ['70',
#   'americans',
#   '30',
#   'older',
#   'received',
#   'covid',
#   '19',
#   'vaccine',
#   'white',
#   'house',
#   'says'],
#  ['vaccination',
#   'update',
#   '71.1',
#   'adult',
#   'new',
#   'yorkers',
#   'received',
#   'least',
#   'one',
#   'vaccine',
#   'dose',
#   '63.4',
#   'completed',
#   '…'],
#  ['1',
#   '"',
#   'cdc',
#   '’',
#   'vaccine',
#   'vaers',
#   'revealed',
#   '900',
#   'cases',
#   'myocarditis',
#   'pericarditis',
#   'among',
#   'ag',
#   '…'],
#  ['philippine',
#   'president',
#   '"',
#   '’',
#   'want',
#   'get',
#   'vaccinated',
#   '’',
#   'arrested',
#   '’',
#   'inject',
#   'vaccine',
#   '…'],
#  ['states',
#   'one',
#   'get',
#   'vaccination',
#   'cowin',
#   'bt',
#   'bengal',
#   '1',
#   'shld',
#   'prfnce',
#   'list',
#   'tmc',
#   'one',
#   'get',
#   '…'],
#  ['freedom',
#   'association',
#   'section',
#   '2',
#   'charter',
#   'would',
#   'young',
#   'people',
#   'take',
#   'vaccine',
#   '…'],
#  ['close',
#   'gap',
#   'biden',
#   'administration',
#   'admits',
#   'reach',
#   'july',
#   '4',
#   'vaccination',
#   'goal',
#   'cdc',
#   'studies',
#   'explain',
#   'vacc',
#   '…'],
#  ['vaccination',
#   'program',
#   'american',
#   'success',
#   'story',
#   'brought',
#   'operation',
#   'warp',
#   'speed',
#   'president',
#   'tr',
#   '…'],
#  ['white',
#   'house',
#   'says',
#   'meeting',
#   'biden',
#   '’',
#   'vaccination',
#   'goal',
#   'less',
#   'important',
#   'pace',
#   'nation',
#   '’',
#   'reopening',
#   'wh',
#   '…'],
#  ['madhya',
#   'pradesh',
#   'saw',
#   'highest',
#   'number',
#   'vaccinations',
#   'across',
#   'states',
#   '16.9',
#   'lakh',
#   'doses',
#   'administered',
#   'yesterday',
#   '…'],
#  ['vaccination',
#   'camp',
#   'set',
#   'p',
#   'mission',
#   'school',
#   'ahmedabad',
#   'police',
#   'aware',
#   'educate',
#   'people',
#   'impo',
#   '…'],
#  ['biden',
#   'administration',
#   'says',
#   'fall',
#   'short',
#   'fourth',
#   'july',
#   'vaccination',
#   'goal',
#   'cnbc',
#   'via'],
#  ['reposting',
#   'hearing',
#   'thousands',
#   'cancelling',
#   'vaccination',
#   'appts',
#   'week',
#   'seeing',
#   '’',
#   'get',
#   'moderna',
#   'instead',
#   '…'],
#  ['santa',
#   'claus',
#   'real',
#   'data',
#   'put',
#   'ccp',
#   'whatever',
#   'real',
#   'numbers',
#   '…'],
#  ['"',
#   'dupage',
#   'covid',
#   '19',
#   'community',
#   'vaccination',
#   'clinic',
#   'modified',
#   'hours',
#   'operation',
#   'beginning',
#   'monday',
#   'june',
#   '21',
#   '…'],
#  ['take',
#   'mrna',
#   'vaccine',
#   'second',
#   'vaccination',
#   '’',
#   'care',
#   'pfizer',
#   'moderna',
#   'gratefu',
#   '…'],
#  ['really',
#   'nice',
#   'points',
#   "'",
#   'piece',
#   'vaccine',
#   'lotteries',
#   'incentives',
#   'also',
#   'gotta',
#   'sa',
#   '…'],
#  ['piece',
#   'write',
#   'goal',
#   'us',
#   'vaccination',
#   'campaign',
#   'achieved',
#   'virus',
#   'lo',
#   '…'],
#  ['could',
#   'get',
#   'highest',
#   'vaccination',
#   'country',
#   'vaccine',
#   'cash',
#   'grab',
#   '5k',
#   'get',
#   'first',
#   'vacci',
#   '…'],
#  ['legitimate', 'sources', 'back', 'statement', 'last', 'checked', '…'],
#  ['70',
#   'americans',
#   'age',
#   '30',
#   'older',
#   'received',
#   'least',
#   'one',
#   'dose',
#   'covid',
#   'vaccine',
#   'white',
#   'house',
#   'said',
#   '…'],
#  ['first',
#   'time',
#   'children',
#   'underlying',
#   'conditions',
#   'young',
#   'get',
#   'vaccinated',
#   'unable',
#   'carry',
#   'memory',
#   '…'],
#  ['madhya',
#   'pradesh',
#   'saw',
#   'highest',
#   'number',
#   'vaccinations',
#   'across',
#   'states',
#   '16.9',
#   'lakh',
#   'doses',
#   'administered',
#   'monday',
#   '…'],
#  ['man',
#   'refusing',
#   'covid',
#   'vaccine',
#   'later',
#   'needs',
#   'lung',
#   'transplant',
#   '"',
#   'knew',
#   'know',
#   'would',
#   'definitely',
#   'went',
#   'th',
#   '…'],
#  ['one',
#   'confirm',
#   'vaccination',
#   'numbers',
#   '20th',
#   'june',
#   '22nd',
#   'june',
#   "i'm",
#   'told',
#   'figur',
#   '…'],
#  ['would', '25', 'persuade', 'get', 'covid', '19', 'vaccine'],
#  ['text',
#   '2nd',
#   'dose',
#   'vaccine',
#   'gotten',
#   'get',
#   'full',
#   'vaccination',
#   'visit',
#   'atleast',
#   'london',
#   'paris',
#   'year',
#   '🙏',
#   '🏾',
#   '🙏',
#   '🏾',
#   '🙏',
#   '🏾'],
#  ['covid',
#   '19',
#   'live',
#   'updates',
#   'white',
#   'house',
#   'publicly',
#   'acknowledges',
#   'biden',
#   'likely',
#   'miss',
#   'july',
#   '4',
#   'vaccination',
#   'goal'],
#  ['new',
#   'el',
#   'monte',
#   'transit',
#   'center',
#   '06-22',
#   '06-24',
#   '06-26',
#   '06-29',
#   '07-01',
#   '07-03',
#   'total',
#   'appointments',
#   'location',
#   '4272',
#   'age',
#   '…'],
#  ['reported',
#   'deaths',
#   'means',
#   "'",
#   'anecdotal',
#   "'",
#   'recognised',
#   'link',
#   'covid',
#   'va',
#   '…'],
#  ['philippine',
#   'president',
#   'threatened',
#   'order',
#   'arrest',
#   'filipinos',
#   'refuse',
#   'covid',
#   '19',
#   'vaccination',
#   'told',
#   '…'],
#  ['philippine',
#   'president',
#   'threatened',
#   'order',
#   'arrest',
#   'filipinos',
#   'refuse',
#   'covid',
#   '19',
#   'vaccination',
#   'told',
#   '…'],
#  ['us', 'expected', 'miss', "biden's", 'july', '4', 'vaccine', 'target'],
#  ['vaccine',
#   'update',
#   '–',
#   '18-39',
#   'age',
#   'group',
#   "we've",
#   'updated',
#   'website',
#   'list',
#   'board',
#   'run',
#   'vaccination',
#   'clinics',
#   'across',
#   'nh',
#   '…'],
#  ['doses', 'vaccine', 'administered', 'state', 'far', '…'],
#  ['doorstep',
#   'vaccination',
#   'camp',
#   'organised',
#   'ghatkopar',
#   'nation',
#   'breaking',
#   'record',
#   'vacc',
#   '…'],
#  ['translation',
#   'covid',
#   'vaccine',
#   'american',
#   'airlines',
#   'reducing',
#   'flights',
#   'due',
#   'shortage',
#   'pilots',
#   'due',
#   '…'],
#  ['botswana',
#   'top',
#   '5',
#   'africa',
#   'rate',
#   'vaccination.under',
#   'mundane',
#   'circumstances',
#   'vaccine',
#   'monopolization',
#   '…'],
#  ["night's",
#   'sleep',
#   'remains',
#   'vaccination',
#   'experience',
#   'thing',
#   'said',
#   'v',
#   '…'],
#  ['head',
#   'white',
#   'house',
#   'covid',
#   '19',
#   'health',
#   'equity',
#   'task',
#   'force',
#   'told',
#   'administration',
#   '…'],
#  ['biden',
#   'administration',
#   'says',
#   'fall',
#   'short',
#   'fourth',
#   'july',
#   'vaccination',
#   'goal',
#   'via',
#   'cnbc'],
#  ['brian',
#   'kemp',
#   'failed',
#   'georgia',
#   'every',
#   'stage',
#   'pandemic',
#   "georgia's",
#   'vaccination',
#   'rate',
#   'well',
#   'na',
#   '…'],
#  ['vaccinated',
#   'defense',
#   'department',
#   'personnel',
#   'americans',
#   'living',
#   'germany',
#   'obtain',
#   'free',
#   'digital',
#   'coronavirus',
#   'v',
#   '…'],
#  ['join',
#   'tonight',
#   'nashville',
#   'pop-up',
#   'vaccination',
#   'clinic',
#   'details'],
#  ['moscow',
#   'announcing',
#   'got',
#   'vaccine',
#   'covid',
#   'past',
#   '6',
#   'months',
#   'negative',
#   'pcr',
#   'v',
#   '…'],
#  ['mean',
#   'covid',
#   'vaccination',
#   'previous',
#   'president',
#   'got',
#   'running',
#   'fact',
#   'current',
#   '…'],
#  ['appears',
#   'u',
#   'r',
#   'intentionally',
#   'slowed',
#   'vaccination',
#   'drive',
#   'per',
#   'ur',
#   'assumptions',
#   'u',
#   '60',
#   'day',
#   '…'],
#  ['report',
#   'us',
#   'recommended',
#   'pause',
#   'giving',
#   'j',
#   'j',
#   'vaccine',
#   'authorities',
#   'examined',
#   '6',
#   'reports',
#   'unusual',
#   'cl',
#   '…'],
#  ['lines',
#   'coping',
#   'florida',
#   '’',
#   'vaccine',
#   'passport',
#   'ban',
#   '—',
#   "'",
#   'ask',
#   "can't",
#   'require',
#   "'",
#   '—',
#   'tho',
#   '…'],
#  ['going',
#   'mandate',
#   'vaccine',
#   'students',
#   'think',
#   "they'd",
#   'least',
#   'continue',
#   'mandate',
#   'masks',
#   'given',
#   '…'],
#  ['accordance',
#   'governor',
#   'state',
#   'get',
#   '1st',
#   'vaccine',
#   'tomorrow',
#   'vaccination',
#   'suspended',
#   '…'],
#  ['broaden',
#   'scope',
#   'vaccinate',
#   'need',
#   'start',
#   'thinking',
#   'box',
#   'tweeted',
#   'early',
#   'tod',
#   '…'],
#  ['truth',
#   'ct',
#   '28',
#   'used',
#   'selection',
#   'vaccine',
#   'breakthrough',
#   'cases',
#   'send',
#   '…'],
#  ['new',
#   'york',
#   'city',
#   'started',
#   'vaccination',
#   '14',
#   'dec',
#   '2020',
#   'doses',
#   'vaccine',
#   'administered',
#   '188',
#   'days',
#   '…'],
#  ['effected',
#   'us',
#   'many',
#   'way',
#   'helped',
#   'moving',
#   'ahead',
#   'fear',
#   'still',
#   'rema',
#   '…'],
#  ['bjp', 'wants', 'show', 'stopped', 'full', 'vaccination', 'days', '…'],
#  ['vaccination',
#   'big',
#   'scam',
#   'person',
#   'takes',
#   'vaccine',
#   'body',
#   'get',
#   'used',
#   'vaccine',
#   'like',
#   'alcohol',
#   'n',
#   '…'],
#  ['would',
#   'like',
#   'know',
#   'delta',
#   'deta',
#   'plus',
#   'variants',
#   'safety',
#   'given',
#   'vaccination',
#   'effecti',
#   '…'],
#  ['biden',
#   'administration',
#   'admits',
#   'reach',
#   'july',
#   '4',
#   'vaccination',
#   'goal',
#   'cdc',
#   'studies',
#   'explain',
#   'vaccination',
#   'slowdown',
#   'lates',
#   '…'],
#  ['’',
#   'wrap',
#   'az',
#   'vaccination',
#   'series',
#   'officially',
#   'dual-dosed',
#   'officially',
#   'take',
#   'bench',
#   'res',
#   '…'],
#  ['mutations',
#   'biological',
#   'pathway',
#   'viruses',
#   'survive',
#   'hostile',
#   'environments',
#   'vaccine',
#   'cause',
#   'muta',
#   '…'],
#  ['county',
#   'county',
#   'work',
#   'low',
#   'vaccination',
#   'percentages',
#   'despite',
#   'widespread',
#   'vaccine',
#   'availa',
#   '…'],
#  ['receiving',
#   'vaccination',
#   'stop',
#   'getting',
#   'virus',
#   'passing',
#   'virus',
#   'case',
#   'po',
#   '…'],
#  ['wathcing',
#   'show',
#   'vaccination',
#   '16',
#   'year-olds',
#   'america',
#   'government',
#   '…'],
#  ['biden',
#   'administration',
#   'admits',
#   'reach',
#   'july',
#   '4',
#   'vaccination',
#   'goal',
#   'cdc',
#   'studies',
#   'explain',
#   'vaccination',
#   'slowdown',
#   'lates',
#   '…'],
#  ['…'],
#  ['miss',
#   'easy',
#   'opportunity',
#   'get',
#   'covid',
#   '19',
#   'vaccination',
#   'every',
#   'month',
#   'summer',
#   'fall',
#   '…'],
#  ['vaccine',
#   'appointments',
#   'available',
#   'walgreens',
#   'duane',
#   'reade',
#   'pfizer',
#   '5716',
#   'avenue',
#   'u',
#   'brooklyn',
#   'ny',
#   '11234',
#   '8',
#   '00',
#   '925',
#   '…'],
#  ['volunteered',
#   'along',
#   'thousands',
#   'people',
#   'test',
#   'new',
#   'novavax',
#   'vaccine',
#   'last',
#   'year',
#   'previ',
#   '…'],
#  ['posted',
#   'mind',
#   'covid',
#   'vaccine',
#   'hesitancy',
#   'one',
#   'plausible-so',
#   '…'],
#  ['’',
#   'boosting',
#   'vaccination',
#   'numbers',
#   'want',
#   'keep',
#   'anxiety',
#   'persona',
#   '…'],
#  ['“',
#   '’',
#   'want',
#   'ask',
#   'people',
#   'anything',
#   'would',
#   'hopefully',
#   'interchanging',
#   'getting',
#   'va',
#   '…'],
#  ['covid',
#   '19',
#   'live',
#   'updates',
#   'quebec',
#   'goes',
#   'green',
#   'monday',
#   'restrictions',
#   'lifting',
#   '–',
#   'legault'],
#  ['excited',
#   'vaccination',
#   'friday',
#   '~',
#   'kinda',
#   'afraid',
#   'body',
#   'diva',
#   'comes',
#   'vaccine',
#   '…'],
#  ['covid',
#   'vaccination',
#   'india',
#   'rural',
#   'areas',
#   'administered',
#   'doses',
#   'urban',
#   'record',
#   'vaccination',
#   'june',
#   '21',
#   'govern',
#   '…'],
#  ['vaccination',
#   'centers',
#   '18-44',
#   'age',
#   'group',
#   '1',
#   'ankura',
#   'hospital',
#   'kukatpally',
#   'cvc',
#   'balanagar',
#   'pin',
#   '500085',
#   'vaccine',
#   '…'],
#  ['get',
#   'answering',
#   'questions',
#   'vaccine',
#   'skeptics',
#   'president-elect',
#   '…'],
#  ['hard', 'vaccination', 'conversations'],
#  ['get',
#   'vaccinated',
#   'county',
#   'mobile',
#   'vaccination',
#   'site',
#   'enter',
#   'drawing',
#   'win',
#   'pair',
#   'padres',
#   'baseball',
#   '…'],
#  ['india',
#   'must',
#   'allow',
#   'approved',
#   'vaccination',
#   'second',
#   'shot',
#   'mix',
#   'allowed',
#   'europe',
#   'gives',
#   'even',
#   'higher',
#   'imm',
#   '…'],
#  ['vaccine',
#   'appointments',
#   'available',
#   'walgreens',
#   'duane',
#   'reade',
#   'moderna',
#   '1612',
#   'westchester',
#   'avenue',
#   'bronx',
#   'ny',
#   '10472',
#   '8',
#   '…'],
#  ['“',
#   'chance',
#   'people',
#   'experience',
#   'new',
#   'illnesses',
#   'die',
#   'pre-existing',
#   'conditi',
#   '…'],
#  ['could', 'turned', 'waited', 'pfizer', 'jab', 'neighbour', '…'],
#  ['asking',
#   "someone's",
#   'covid',
#   '19',
#   'vaccination',
#   'status',
#   'delicate',
#   'topic',
#   'several',
#   'legal',
#   'ethics',
#   'employment',
#   'eti',
#   '…'],
#  ['vaccine',
#   'hesitancy',
#   'still',
#   'prevalent',
#   '…',
#   'tried',
#   'convincing',
#   'household',
#   'help',
#   'vaccination',
#   'told',
#   '…'],
#  ['voting',
#   'requirements',
#   'less',
#   'getting',
#   'covid',
#   'vaccine',
#   'rules',
#   'must',
#   'bri',
#   '…'],
#  ['biden',
#   'administration',
#   'says',
#   'fall',
#   'short',
#   'fourth',
#   'july',
#   'vaccination',
#   'goal'],
#  ['details', 'nhs', 'covid', '19', 'vaccination', 'programme', 'found', '…'],
#  ['’',
#   'age',
#   'band',
#   'vaccination',
#   'data',
#   'widely',
#   'publicized',
#   'uk',
#   'canada',
#   'featu',
#   '…'],
#  ['let',
#   '’',
#   'help',
#   'end',
#   'covid',
#   '19',
#   'pandemic',
#   'good',
#   'find',
#   'vaccination',
#   'location',
#   'near',
#   'using',
#   'ca',
#   'public',
#   'health',
#   '’',
#   'tur',
#   '…'],
#  ['let',
#   '’',
#   'help',
#   'end',
#   'covid',
#   '19',
#   'pandemic',
#   'good',
#   'find',
#   'vaccination',
#   'location',
#   'near',
#   'using',
#   'ca',
#   'public',
#   'health',
#   '’',
#   'tur',
#   '…'],
#  ['let',
#   '’',
#   'help',
#   'end',
#   'covid',
#   '19',
#   'pandemic',
#   'good',
#   'find',
#   'vaccination',
#   'location',
#   'near',
#   'using',
#   'ca',
#   'public',
#   'health',
#   '’',
#   'tur',
#   '…'],
#  ['polio',
#   'vaccination',
#   'started',
#   'eradication',
#   'polio',
#   'doses',
#   'given',
#   '…'],
#  ["i'll",
#   'getting',
#   'kids',
#   'vaccine',
#   'soon',
#   'available',
#   'though',
#   'think',
#   'prioritizing',
#   'vacc',
#   '…'],
# ...
#   '…'],
#  ['org',
#   'awarnance',
#   'vaccination',
#   'registration',
#   'camp',
#   'potha',
#   'katera',
#   '…'],
#  ['ndtv',
#   'ravish',
#   'kumar',
#   '|',
#   "india's",
#   'covid',
#   'vaccination',
#   'drive',
#   '|',
#   'polio',
#   'vaccine',
#   '|',
#   'sa',
#   'via'],
#  ['check',
#   'umrf',
#   'help',
#   'city',
#   'memphis',
#   'reach',
#   'vaccination',
#   'goal',
#   'whbq',
#   'fox',
#   '13',
#   'memphis',
#   '…'],
#  ['health',
#   'ministry',
#   'urged',
#   'rapid',
#   'teens',
#   'began',
#   'working',
#   'measures',
#   'curb',
#   'infections',
#   'li',
#   '…'],
#  ['dr',
#   'bogoch',
#   'would',
#   'able',
#   'clarify',
#   'study',
#   'think',
#   'public',
#   '’',
#   'assumption',
#   'wa',
#   '…'],
#  ["'",
#   "i'll",
#   'inject',
#   'vaccine',
#   'butt',
#   "'",
#   'philippines',
#   'president',
#   'threatens',
#   'arrest',
#   'refuse',
#   'vaccination'],
#  ['org', 'awarnance', 'vaccination', 'registration', 'camp', 'darana', '…'],
#  ['org', 'awarnance', 'vaccination', 'registration', 'camp', 'poonch', '…'],
#  ['walk-in',
#   'clinic',
#   'open',
#   'north',
#   'ridge',
#   'centre',
#   '4:00',
#   'pm',
#   'thanks',
#   'working',
#   "today's",
#   'clinic',
#   '…'],
#  ['sir',
#   'get',
#   'vaccine',
#   'even',
#   'standing',
#   'q',
#   '2',
#   'hours',
#   'said',
#   '80',
#   'tokens',
#   'n',
#   'vaccination',
#   'ended',
#   '1',
#   '…'],
#  ['new', 'blog', 'vaccination', 'update', 'three-quarters', '…'],
#  ['another',
#   'reason',
#   'school',
#   'shut',
#   'since',
#   'last',
#   'year',
#   'way',
#   'vaccination',
#   'use',
#   'zydus',
#   'cadila',
#   'vaccine',
#   '…'],
#  ['’',
#   'official',
#   'summer',
#   'getting',
#   'vaccine',
#   'great',
#   'way',
#   'way',
#   'kick',
#   'find',
#   'nearest',
#   'vacci',
#   '…'],
#  ['worrying'],
#  ['hopefully',
#   'push',
#   'child',
#   'vaccination',
#   'otherwise',
#   'many',
#   'children',
#   'get',
#   'infected',
#   '…'],
#  ['white',
#   'house',
#   'says',
#   'meeting',
#   'biden',
#   '’',
#   'vaccination',
#   'goal',
#   'less',
#   'important',
#   'pace',
#   'nation',
#   '’',
#   'reopening',
#   'wh',
#   '…'],
#  ['vaccination',
#   'lottery',
#   'send',
#   'electric',
#   'vehicles',
#   'ccp',
#   'encourages',
#   'vaccination',
#   'many',
#   'tricks',
#   'june',
#   '22',
#   '…'],
#  ['three', 'years', 'long', 'wait', 'global', 'vaccine', 'rollout'],
#  ['mark',
#   'anti',
#   'covid',
#   'inj',
#   'untested',
#   'gene',
#   'therapy',
#   'products',
#   'dangerously',
#   'mislabeled',
#   '"',
#   'vaccin',
#   '…'],
#  ['’',
#   'covid',
#   '19',
#   'vaccination',
#   'coverage',
#   'crosses',
#   'landmark',
#   '29',
#   'cr',
#   'second',
#   'day',
#   'new',
#   'phase',
#   '…'],
#  ['sir',
#   'please',
#   'allow',
#   'private',
#   'hospital',
#   'provide',
#   'covishield',
#   'vaccine',
#   'international',
#   'students',
#   'within',
#   'gap',
#   '28',
#   '…'],
#  ['maharashtra',
#   'vaccine',
#   'drive',
#   'started',
#   'age',
#   '30yrs',
#   'vaccination',
#   'us',
#   '30'],
#  ['time',
#   'build',
#   'good',
#   'nos',
#   'antibodies',
#   '14-18',
#   'days',
#   'post',
#   'vaccination',
#   'cov',
#   '…'],
#  ['initiated',
#   'one',
#   'fastest',
#   'vaccine',
#   'developments',
#   'history',
#   'started',
#   'production',
#   'millio',
#   '…'],
#  ['hb',
#   '248',
#   'already',
#   'things',
#   'prohibit',
#   'vaccine',
#   'mandate',
#   'proof',
#   'vaccination'],
#  ['recently',
#   'discovered',
#   'delta',
#   'variant',
#   'coronavirus',
#   'people',
#   'questioning',
#   'vaccine',
#   'enough',
#   '…'],
#  ['recently',
#   'discovered',
#   'delta',
#   'variant',
#   'coronavirus',
#   'people',
#   'questioning',
#   'vaccine',
#   'enough',
#   '…'],
#  ['bjp',
#   'ppl',
#   'hailing',
#   'record',
#   '86',
#   'lakh',
#   'covid',
#   'vaccine',
#   'read',
#   'eye',
#   'opening',
#   'story',
#   '…'],
#  ['unfortunately',
#   'decision',
#   'go',
#   '2',
#   'major',
#   'vaccine',
#   'suppliers',
#   'beneficial',
#   'south',
#   'africa',
#   'ha',
#   '…'],
#  ['spain',
#   'covid',
#   'vaccine',
#   'tenerife',
#   'gran',
#   'canaria',
#   'residents',
#   '30',
#   'years',
#   'age',
#   'request',
#   'vaccination'],
#  ['vice',
#   'president',
#   'leni',
#   'robredo',
#   'calling',
#   'volunteer',
#   'doctors',
#   'nurses',
#   'help',
#   'administer',
#   'vaccin',
#   '…'],
#  ['walgreens',
#   'plans',
#   'give',
#   '25',
#   'store',
#   'credit',
#   'anyone',
#   'gets',
#   'covid',
#   '19',
#   'vaccination',
#   'next',
#   'several',
#   '…'],
#  ['☻',
#   'yesterday',
#   '56',
#   'lakh',
#   'given',
#   'area',
#   '30',
#   'lakh',
#   'area',
#   'wrt',
#   'yr',
#   'debate',
#   'statem',
#   '…'],
#  ['states',
#   'govt',
#   'accusing',
#   'centre',
#   'vaccine',
#   'drive',
#   'state',
#   'seeing',
#   '…'],
#  ['“', 'countries', 'requiring', '…', 'vaccination', 'entry', '”', 'see', '…'],
#  ['least',
#   'delhi',
#   'govt',
#   'consistent',
#   'applying',
#   'daily',
#   'vaccine',
#   'doses',
#   'get',
#   'enough',
#   'vaccine',
#   'supply',
#   'moreove',
#   '…'],
#  ['anyone',
#   'get',
#   'covid',
#   '19',
#   'develop',
#   'serious',
#   'symptoms',
#   'protect',
#   'around',
#   'registering',
#   'recei',
#   '…'],
#  ['’',
#   'easier',
#   'ever',
#   'get',
#   'inoculated',
#   'covid',
#   '19',
#   'people',
#   'would',
#   'put',
#   'away',
#   '…'],
#  ['prohibits',
#   'mandatory',
#   'covid',
#   '19',
#   'vaccinations',
#   'requirements',
#   'proof',
#   'discrimination',
#   'based',
#   'covid',
#   '19',
#   'vaccinat',
#   '…'],
#  ['"',
#   'prohibit',
#   'mandatory',
#   'covid',
#   '19',
#   'vaccination',
#   'vaccine',
#   'proof',
#   '"',
#   'act',
#   'interestingly',
#   'assigned',
#   '…'],
#  ['white',
#   'house',
#   'says',
#   'meeting',
#   'biden',
#   '’',
#   'vaccination',
#   'goal',
#   'less',
#   'important',
#   'pace',
#   'nation',
#   '’',
#   'reopening',
#   'wh',
#   '…'],
#  ["i've",
#   'heard',
#   'anecdotally',
#   'people',
#   'vaccine',
#   'home',
#   'country',
#   '+',
#   '…'],
#  ['nuremberg',
#   'please',
#   'stop',
#   'melodramatic',
#   'vaccination',
#   'protects',
#   'elderly',
#   'sho',
#   '…'],
#  ['ndtv',
#   'ravish',
#   'kumar',
#   '|',
#   "india's",
#   'covid',
#   'vaccination',
#   'drive',
#   '|',
#   'polio',
#   'vaccine',
#   '|',
#   'sa',
#   'via'],
#  ['blame',
#   'system',
#   'politicians',
#   'instead',
#   'playing',
#   'blame',
#   'game',
#   'let',
#   'us',
#   'accept',
#   '…'],
#  ['drop-in',
#   'vaccination',
#   'clinics',
#   'astrazeneca',
#   'drop-in',
#   'clinics',
#   '40s',
#   'first',
#   'astra',
#   '…'],
#  ['feel',
#   'pain',
#   'nurse',
#   'already',
#   'injected',
#   'vaccine',
#   'monitored',
#   'vaccinati',
#   '…'],
#  ['effective',
#   'peer-reviewed',
#   'outpatient',
#   'treatment',
#   'protocols',
#   'available',
#   'people',
#   'aware',
#   '…'],
#  ['california',
#   'unveiled',
#   'website',
#   'lets',
#   'users',
#   'verify',
#   'identities',
#   'get',
#   'digital',
#   'copies',
#   'covid',
#   '19',
#   '…'],
#  ['…'],
#  ['reach',
#   'people',
#   'want',
#   '2',
#   'b',
#   'vaccinated',
#   'vaccination',
#   'hv',
#   'smart',
#   'peop',
#   '…'],
#  ['vaers',
#   'cannot',
#   'determine',
#   'whether',
#   'vaccine',
#   'caused',
#   'something',
#   '…'],
#  ['saying', 'stay', 'force', '…'],
#  ['share',
#   'max',
#   'aap',
#   'exposes',
#   'dual',
#   'face',
#   'modi',
#   'govt',
#   'vaccination',
#   'delhi',
#   'receive',
#   'single',
#   'dose',
#   'va',
#   '…'],
#  ['today',
#   'got',
#   'second',
#   'shot',
#   'covid',
#   'vaccine',
#   'also',
#   'try',
#   'work',
#   'requests',
#   'promised',
#   'may',
#   'tak',
#   '…'],
#  ['centre',
#   'covid',
#   'vaccination',
#   'drive',
#   'balance',
#   'doses',
#   'direct',
#   'state',
#   'procurement',
#   'pending',
#   'vaccine',
#   'manufactur',
#   '…'],
#  ['covid',
#   '19',
#   'vaccination',
#   'providers',
#   'cannot',
#   'charge',
#   'vaccine',
#   '…'],
#  ['rare',
#   'neurological',
#   'disorder',
#   'documented',
#   'small',
#   'number',
#   'people',
#   'following',
#   'covid',
#   '19',
#   'vaccination',
#   'neuroscience',
#   'new',
#   '…'],
#  ['vaccine',
#   'psa',
#   'need',
#   'change',
#   'vaccine',
#   'appointment',
#   'gov',
#   'booking',
#   'site',
#   'check',
#   'availability',
#   '…'],
#  ['madness',
#   'government',
#   'must',
#   'focus',
#   'eliminating',
#   'virus',
#   'vaccination',
#   'rather',
#   'trying',
#   'manage',
#   '…'],
#  ['📣',
#   'aged',
#   '40',
#   'need',
#   'second',
#   'dose',
#   'astrazeneca',
#   'vaccine',
#   '2nd',
#   'dose',
#   '8',
#   'weeks',
#   'come',
#   '…'],
#  ['org', 'awarnance', 'vaccination', 'registration', 'camp', 'darana', '…'],
#  ['reminder',
#   '’',
#   'wait',
#   'vaccinate',
#   'find',
#   'vaccination',
#   'location',
#   'close',
#   '…'],
#  ['covid',
#   '19',
#   'vaccine',
#   'clinic',
#   'today',
#   'center',
#   'clayton',
#   '2:00',
#   '9:00',
#   'p',
#   'pfizer',
#   'vaccine',
#   'wil',
#   '…'],
#  ['vaccination',
#   'centre',
#   'equipped',
#   'doctors',
#   'reaction',
#   'caused',
#   'vaccine',
#   'recieptant',
#   '…'],
#  ['org', 'awarnance', 'vaccination', 'registration', 'camp', 'darana', '…'],
#  ['mobile',
#   'covid',
#   '19',
#   'drop-in',
#   'vaccination',
#   'site',
#   'today',
#   '9:30',
#   '3:30',
#   'p',
#   'elks',
#   'lodge',
#   'el',
#   'cajon',
#   '1400',
#   'e',
#   'washington',
#   '…'],
#  ['health',
#   'services',
#   'three',
#   'vaccine',
#   'types',
#   '—',
#   'pfizer',
#   'moderna',
#   'j',
#   'j',
#   '—',
#   'available',
#   'clinic',
#   'appointments',
#   'ar',
#   '…'],
#  ['pollachi',
#   'private',
#   'hospitals',
#   'providing',
#   'vaccination',
#   'almost',
#   'hospitals',
#   'providing',
#   'coimbato',
#   '…'],
#  ['org', 'awarnance', 'vaccination', 'registration', 'camp', 'darana', '…'],
#  ['already',
#   '70',
#   'protected',
#   'usa',
#   'immunity',
#   'infection',
#   'recovery',
#   'counted',
#   'million',
#   '…'],
#  ['along',
#   'core',
#   'hosting',
#   'mini',
#   'covid',
#   '19',
#   'vaccination',
#   'event',
#   'sat',
#   'june',
#   '26',
#   '9a',
#   '12',
#   '…'],
#  ['"',
#   'choose',
#   'vaccine',
#   'jailed',
#   '”',
#   'duterte',
#   'said',
#   'televised',
#   'address',
#   'monday',
#   'following',
#   'reports',
#   '…'],
#  ['biden',
#   'failing',
#   'vaccination',
#   'goal',
#   'definitely',
#   'nothing',
#   "cdc's",
#   'absolutely',
#   'horrid',
#   'communications',
#   '…'],
#  ['correct',
#   'governments',
#   'using',
#   'vaccines',
#   'vaccine',
#   'passports',
#   'part',
#   'exit',
#   'str',
#   '…'],
#  ['people',
#   'prior',
#   'exposure',
#   'virus',
#   'mount',
#   'stronger',
#   'immune',
#   'response',
#   'vaccine',
#   'whose',
#   '…'],
#  ['u',
#   'hit',
#   "biden's",
#   '70',
#   'covid',
#   'vaccination',
#   'goal',
#   'july',
#   '4',
#   'white',
#   'house',
#   'official',
#   'admits',
#   'cbs',
#   'news'],
#  ['philippine',
#   'president',
#   'threatened',
#   'order',
#   'arrest',
#   'filipinos',
#   'refuse',
#   'covid',
#   '19',
#   'vaccination',
#   'told',
#   '…'],
#  ['📢',
#   'employers',
#   'access',
#   'national',
#   'campaign',
#   'resources',
#   'use',
#   'workplace',
#   'support',
#   'employees',
#   'take',
#   '…'],
#  ['initiative', 'offline', 'rural', 'area', 'vaccination', 'today', '…'],
#  ['june',
#   '22',
#   'numbers',
#   'released',
#   'ministry',
#   'health',
#   'show',
#   'health',
#   'officials',
#   'administered',
#   '199,535',
#   'vaccine',
#   'doses',
#   '…'],
#  ['new',
#   'brunswicker',
#   '’',
#   'lead',
#   'atlantic',
#   'canada',
#   'vaccination',
#   'efforts',
#   'widespread',
#   'access',
#   'vaccines',
#   'community',
#   'pharmacie',
#   '…'],
#  ['wrong',
#   'records',
#   'shown',
#   'yesterday',
#   '86',
#   'lakhs',
#   'vaccinated',
#   'day',
#   'shown',
#   'vaccination',
#   'purpo',
#   '…'],
#  ["'",
#   "i'll",
#   'inject',
#   'vaccine',
#   'butt',
#   "'",
#   'philippines',
#   'president',
#   'threatens',
#   'arrest',
#   'refuse',
#   'vaccination'],
#  ['three',
#   'vaccines',
#   'available',
#   'walk-in',
#   'covid',
#   '19',
#   'vaccination',
#   'clinic',
#   'barnegat',
#   'library',
#   'next',
#   '…'],
#  ['philippine',
#   'president',
#   'rodrigo',
#   'duterte',
#   'threatens',
#   'citizens',
#   'jail',
#   'refusing',
#   'vaccination',
#   'daily',
#   'caller',
#   'holy',
#   '…'],
#  ['signs',
#   'high',
#   'rates',
#   'covid',
#   'vaccine-related',
#   'illness',
#   'death',
#   'adults',
#   'present',
#   'april',
#   '2021',
#   '…'],
#  ['covid',
#   'cases',
#   'rising',
#   'imperative',
#   'work',
#   'together',
#   'testing',
#   'regularly',
#   '…'],
#  ['course',
#   'immunization',
#   'prevents',
#   'transmission',
#   'doctors',
#   'pushing',
#   'post',
#   'vaccination',
#   'masking',
#   'undermining',
#   'vaccine',
#   '…'],
#  ['…'],
#  ["'",
#   "i'll",
#   'inject',
#   'vaccine',
#   'butt',
#   "'",
#   'philippines',
#   'president',
#   'threatens',
#   'arrest',
#   'refuse',
#   'vaccination'],
#  ['back',
#   'second',
#   'need',
#   'information',
#   'regarding',
#   'covid',
#   'vaccination',
#   'anything',
#   'might',
#   'concerning',
#   'vaccine',
#   'would',
#   'help',
#   'lot'],
#  ['temporary',
#   'vaccination',
#   'centre',
#   'opening',
#   'road',
#   'college',
#   'weds',
#   '23',
#   'june',
#   'undergrads',
#   'taught',
#   'post',
#   '…'],
#  ['upper',
#   'caste',
#   'hindus',
#   'lead',
#   'pro-vaccine',
#   'count',
#   'sts',
#   'vaccination'],
#  ['host',
#   'free',
#   'covid',
#   '19',
#   'vaccination',
#   'clinic',
#   'mcps',
#   'students',
#   '12',
#   'years',
#   'older',
#   'using',
#   'pfizer',
#   'vacci',
#   '…'],
#  ['➡',
#   "️india's",
#   'covid',
#   '19',
#   'vaccination',
#   'coverage',
#   'crosses',
#   'landmark',
#   '29',
#   'cr',
#   '➡',
#   '️on',
#   '2nd',
#   'day',
#   'new',
#   'p',
#   '…'],
#  ["what's",
#   'happened',
#   'vaccination',
#   'doses',
#   'eu',
#   'last',
#   'week',
#   'big',
#   'fall'],
#  ['➡',
#   "️india's",
#   'covid',
#   '19',
#   'vaccination',
#   'coverage',
#   'crosses',
#   'landmark',
#   '29',
#   'cr',
#   '➡',
#   '️on',
#   '2nd',
#   'day',
#   'new',
#   'p',
#   '…'],
#  ['mark',
#   'anti',
#   'covid',
#   'inj',
#   'untested',
#   'gene',
#   'therapy',
#   'products',
#   'dangerously',
#   'mis',
#   '…'],
#  ['quebec',
#   'reports',
#   '84',
#   'new',
#   'covid',
#   '19',
#   'cases',
#   'hospitalizations',
#   'fall',
#   'nine-month',
#   'low'],
#  ['💰',
#   'visa',
#   'debit',
#   '💰',
#   'card',
#   'first',
#   '20',
#   'people',
#   'receive',
#   'covid',
#   '19',
#   'vaccine',
#   'today',
#   'hillyard',
#   'library',
#   'vacci',
#   '…'],
#  ['new',
#   'york',
#   'city',
#   'started',
#   'vaccination',
#   '14',
#   'dec',
#   '2020',
#   'doses',
#   'vaccine',
#   'administered',
#   '188',
#   'days',
#   '=',
#   '98,34',
#   '847',
#   '…'],
#  ['philippine',
#   'president',
#   'rodrigo',
#   'duterte',
#   'threatens',
#   'citizens',
#   'jail',
#   'refusing',
#   'vaccination',
#   'daily',
#   'caller'],
#  ['covid',
#   '19',
#   'vaccination',
#   'update',
#   'day',
#   '158',
#   '6.55',
#   'cr',
#   'vaccine',
#   'doses',
#   'administered',
#   'age',
#   'g',
#   '…'],
#  ['“',
#   'agree',
#   'vaccinated',
#   'leave',
#   'philippines',
#   'go',
#   'india',
#   'want',
#   'somewhere',
#   'america',
#   '"'],
#  ['“',
#   'agree',
#   'vaccinated',
#   'leave',
#   'philippines',
#   'go',
#   'india',
#   'want',
#   'somewhere',
#   'america',
#   '"'],
#  ['also', '’', 'want', 'mix', 'doses', 'find', 'vaccine', '…'],
#  ["'",
#   "i'll",
#   'inject',
#   'vaccine',
#   'butt',
#   "'",
#   'philippines',
#   'president',
#   'threatens',
#   'arrest',
#   'refuse',
#   'vaccination'],
#  ['till',
#   'yesterday',
#   'two',
#   'vaccination',
#   'centres',
#   'government',
#   'listed',
#   'cowin',
#   'portal',
#   'today',
#   'reg',
#   '…'],
#  ['starting',
#   'june',
#   '23',
#   'residents',
#   'use',
#   'self-serve',
#   'booking',
#   'system',
#   'schedule',
#   'vaccination',
#   'appointments',
#   'pub',
#   '…'],
#  ['begging',
#   'begging',
#   'stop',
#   'thinking',
#   'vaccination',
#   'individual',
#   'protection',
#   'thing',
#   'start',
#   'thinki',
#   '…'],
#  ['achieved',
#   '80',
#   'lakh',
#   'doses',
#   'number',
#   'increasing',
#   'vaccine',
#   'production',
#   'slowing',
#   '…'],
#  ['covid',
#   '19',
#   'live',
#   'updates',
#   'quebec',
#   'reports',
#   '84',
#   'new',
#   'cases',
#   'hospitalizations',
#   'fall',
#   'nine-month',
#   'low'],
#  ['report',
#   'post',
#   'vax',
#   'problems',
#   'would',
#   'make',
#   'people',
#   'want',
#   'get',
#   'seem',
#   '…'],
#  ['philippine',
#   'president',
#   'rodrigo',
#   'duterte',
#   'threatens',
#   'citizens',
#   'jail',
#   'refusing',
#   'vaccination'],
#  ['breaking',
#   'u',
#   'hit',
#   "biden's",
#   '70',
#   'covid',
#   'vaccination',
#   'goal',
#   'july',
#   '4',
#   'white',
#   'house',
#   'official',
#   'admits'],
#  ['bless',
#   'vaccine',
#   'lady',
#   'vaccination',
#   '1',
#   'minute',
#   'hate',
#   'drag',
#   'shit',
#   'small',
#   'talk',
#   '😭'],
#  ['point',
#   'think',
#   'vaccine',
#   'conspiracies',
#   'primary',
#   'driver',
#   'older',
#   'adults',
#   'repub',
#   '…'],
#  ['yes', 'track', 'excess', '…'],
#  ['understanding', 'well', 'taking', 'vaccine', 'choosing', 'sever', '…'],
#  ['india',
#   'colliding',
#   'politician',
#   'vaccine',
#   'availability',
#   'trading',
#   'credit',
#   'usual',
#   'attention',
#   '…'],
#  ['india',
#   '’',
#   'covid',
#   '19',
#   'vaccination',
#   'coverage',
#   'crosses',
#   'landmark',
#   '29',
#   'cr',
#   'second',
#   'day',
#   'new',
#   'phase',
#   'covid',
#   '19',
#   'vacc',
#   '…'],
#  ...]

# %%
negative_tokens = []
for tweet in negatives:
    for token in tweet:
        negative_tokens.append(token)

# %%
len(negative_tokens)
# Out:
# 53884

# %%
token_list = list(set(negative_tokens))

# %%
token_counts = [negative_tokens.count(x) for x in token_list]

# %%
len(token_counts) == len(token_list)
# Out:
# True

# %%
token_dict = {
    "token" : token_list,
    "count" : token_counts
}

# %%
token_df = pd.DataFrame.from_dict(token_dict)

# %%
token_df.sort_values(by="count", ascending=False, inplace=True)

# %%
1418/len(negatives) # "Available"
# Out:
# 0.3256775378961874

# %%
948/len(negatives) #appointments
# Out:
# 0.21773082223242995

# %%
445/len(negatives) # slot
# Out:
# 0.10220486908589803

# %%
936 / len(negatives) # walgreens
# Out:
# 0.21497473587505742

# %%
token_df.head(50)
# Out:
#              token  count
# 3185             …   3565
# 623        vaccine   2652
# 5855   vaccination   1942
# 6745     available   1418
# 5200  appointments    948
# 3910     walgreens    936
# 6264          sign    895
# 1956           jun    894
# 2423          code    894
# 3312           zip    892
# 1769           jul    891
# 2091         covid    759
# 1183       chicago    585
# 1113             2    538
# 5314            22    515
# 2220            19    479
# 3604          slot    445
# 2587             6    430
# 1736            23    428
# 4355             ’    355
# 3301           age    310
# 3847           get    286
# 603              +    273
# 639           2021    231
# 5975          june    231
# 6393          date    222
# 3759        people    218
# 69               "    208
# 2353            18    203
# 88           doses    195
# 3800          dose    184
# 598          first    153
# 1768         today    151
# 6672         india    144
# 3449             1    139
# 2784     covishiel    135
# 79               8    128
# 3559           one    126
# 1344    vaccinated    125
# 4202           day    125
# 4557             '    121
# 2125         drive    113
# 5714            45     98
# 6469           new     97
# 5602          lakh     95
# 2860          need     94
# 956   administered     92
# 1227         24-06     92
# 2410        centre     90
# 1241        second     86
