# %% [markdown]
# # USDA Unemployment
# <hr>

# %%
import pandas as pd
import os

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data
# ## US Unemployment data by county
# Economic Research Service
# U.S. Department of Agriculture
# link:

# %% [markdown]
# ##  Contants
# <hr>

# %%
stats_master_list = ['Vermont',
 'Mississippi',
 'Maine',
 'Montana',
 'Washington',
 'District of Columbia',
 'Texas',
 'Alabama',
 'Michigan',
 'Maryland',
 'Rhode Island',
 'South Dakota',
 'Nebraska',
 'Virginia',
 'Florida',
 'Utah',
 'Louisiana',
 'Missouri',
 'Massachusetts',
 'South Carolina',
 'Pennsylvania',
 'Tennessee',
 'Minnesota',
 'Idaho',
 'Alaska',
 'Oklahoma',
 'North Dakota',
 'Arkansas',
 'Georgia',
 'New Hampshire',
 'Indiana',
 'Puerto Rico',
 'New Jersey',
 'Delaware',
 'West Virginia',
 'Colorado',
 'New York',
 'Kansas',
 'Arizona',
 'Ohio',
 'Hawaii',
 'Illinois',
 'Oregon',
 'North Carolina',
 'California',
 'Kentucky',
 'Wyoming',
 'Iowa',
 'Nevada',
 'Connecticut',
 'Wisconsin',
 'New Mexico']

# %%
# column Names

columns = [                         'FIPS ',                           'Name',
                                 '2012',                             2013,
                                   2014,                             2015,
                                   2016,                             2017,
                                   2018,                             2019,
                                 '2020', 'Median Household Income (2019)',
          '% of State Median HH Income']

# %%
"""
Duplicate check 3
from 
https://thispointer.com/python-3-ways-to-check-if-there-are-duplicates-in-a-list/
"""
def checkIfDuplicates_3(listOfElems):
    ''' Check if given list contains any duplicates '''    
    for elem in listOfElems:
        if listOfElems.count(elem) > 1:
            return True
    return False

# %% [markdown]
# ## File managment
# <hr>

# %%
files = os.listdir("../data_raw/USDA_gov-unemplyment/")

# %%
# remove mac file 
files.remove('.DS_Store')

# %%
files
# Out:
# ['UnemploymentReport (45).xlsx',
#  'UnemploymentReport (24).xlsx',
#  'UnemploymentReport (19).xlsx',
#  'UnemploymentReport (26).xlsx',
#  'UnemploymentReport (47).xlsx',
#  'UnemploymentReport (8).xlsx',
#  'UnemploymentReport (43).xlsx',
#  'UnemploymentReport.xlsx',
#  'UnemploymentReport (22).xlsx',
#  'UnemploymentReport (20).xlsx',
#  'UnemploymentReport (39).xlsx',
#  'UnemploymentReport (41).xlsx',
#  'UnemploymentReport (27).xlsx',
#  'UnemploymentReport (46).xlsx',
#  'UnemploymentReport (9).xlsx',
#  'UnemploymentReport (44).xlsx',
#  'UnemploymentReport (18).xlsx',
#  'UnemploymentReport (25).xlsx',
#  'UnemploymentReport (21).xlsx',
#  'UnemploymentReport (40).xlsx',
#  'UnemploymentReport (38).xlsx',
#  'UnemploymentReport (42).xlsx',
#  'UnemploymentReport (23).xlsx',
#  'UnemploymentReport (12).xlsx',
#  'UnemploymentReport (1).xlsx',
#  'UnemploymentReport (36).xlsx',
#  'UnemploymentReport (34).xlsx',
#  'UnemploymentReport (3).xlsx',
#  'UnemploymentReport (10).xlsx',
#  'UnemploymentReport (29).xlsx',
#  'UnemploymentReport (14).xlsx',
#  'UnemploymentReport (51).xlsx',
#  'UnemploymentReport (30).xlsx',
#  'UnemploymentReport (7).xlsx',
#  'UnemploymentReport (48).xlsx',
#  'UnemploymentReport (5).xlsx',
#  'UnemploymentReport (32).xlsx',
#  'UnemploymentReport (16).xlsx',
#  'UnemploymentReport (2).xlsx',
#  'UnemploymentReport (35).xlsx',
#  'UnemploymentReport (11).xlsx',
#  'UnemploymentReport (13).xlsx',
#  'UnemploymentReport (37).xlsx',
#  'UnemploymentReport (33).xlsx',
#  'UnemploymentReport (4).xlsx',
#  'UnemploymentReport (17).xlsx',
#  'UnemploymentReport (50).xlsx',
#  'UnemploymentReport (15).xlsx',
#  'UnemploymentReport (28).xlsx',
#  'UnemploymentReport (6).xlsx',
#  'UnemploymentReport (49).xlsx',
#  'UnemploymentReport (31).xlsx']

# %% [markdown]
# # Create master DataFrame
# <hr>

# %%
# Concat 

# create master file 
master_df = pd.DataFrame(columns = columns)
state_name_list = []

# LOOP 
for file in files:
    # read excel file
    _df = pd.read_excel('../data_raw/USDA_gov-unemplyment/'+file, skiprows=2)
    # read state_name
    state_name = _df.iloc[0,1]
    

# DROP
    #drop row 0
    _df.drop(0, inplace = True)
    
    # Drop last 2 rows 
    _df.drop(_df.tail(1).index, inplace = True)

    # work around to drop NaN column 
    _temp_df = _df.iloc[:,0:12]
    
    # work around to drop NaN column 
    _temp_df['% of State Median HH Income'] = _df['% of State Median HH Income']
    
# add Column for STATE name
    # add state column 
    _temp_df['state'] = state_name
    state_name_list.append(state_name)
    
    # Concat 
    master_df = pd.concat([master_df, _temp_df])

# %% [markdown]
# <br>

# %% [markdown]
# ## Dataframe clean up
# <hr>

# %%
# reset Index
master_df.reset_index(drop = True, inplace = True )

# %%
# Rename columns 
master_df.rename(columns = {'FIPS ':'FIPS'}, inplace = True)

# %% [markdown]
# <br>

# %%
master_df.shape
# Out:
# (3269, 14)

# %%
master_df.head()
# Out:
#     FIPS                   Name  2012  2013  2014  2015  2016  2017  2018  \
# 0  50001     Addison County, VT   4.4   4.1   3.8   3.4   2.9   2.8   2.5
# 1  50003  Bennington County, VT   5.7   5.2   4.7   4.2   3.6   3.7   3.1
# 2  50005   Caledonia County, VT   6.1   5.3   4.9   4.6   4.0   3.7   3.2
# 3  50007  Chittenden County, VT   3.7   3.4   3.1   2.7   2.4   2.3   2.0
# 4  50009       Essex County, VT   7.8   6.7   6.0   5.7   4.8   4.7   3.6
#
#    2019  2020  Median Household Income (2019)  % of State Median HH Income  \
# 0   2.3   5.0                         73574.0                     1.162435
# 1   2.9   6.6                         56948.0                     0.899752
# 2   2.9   5.8                         50942.0                     0.804860
# 3   1.7   4.8                         76483.0                     1.208396
# 4   3.1   6.5                         45796.0                     0.723556
#
#      state
# 0  Vermont
# 1  Vermont
# 2  Vermont
# 3  Vermont
# 4  Vermont

# %% [markdown]
# ## Remove rows with all nan's
# <hr>

# %%
# identify Nans in FIPS row 
nan_rows = master_df[ master_df['FIPS'].isnull()].index
print(len(nan_rows))
# Out:
# 0

# %%
# remove rows with all Nans
master_df.drop(nan_rows, inplace = True)

# %%
master_df.shape
# Out:
# (3214, 14)

# %% [markdown]
# # Sanity Check
# <hr>

# %%
# unique Count of stats

# %%
master_df['state'].nunique()
# Out:
# 52

# %%
len(state_name_list)
# Out:
# 52

# %%
# checks if there are duplicates in state list
checkIfDuplicates_3(state_name_list)
# Out:
# False

# %%
master_df['state'].nunique()
# Out:
# 52

# %%
# random peek
df = pd.read_excel('../data_raw/USDA_gov-unemplyment/UnemploymentReport (14).xlsx', skiprows=2)
df.head()
# Out:
#    FIPS                     Name  2012  2013  2014  2015  2016  2017  2018  \
# 0  18000                 Indiana   8.2   7.5   5.9   4.8   4.4   3.5   3.4
# 1  18001        Adams County, IN   6.9   6.0   4.6   3.8   3.5   2.6   2.6
# 2  18003        Allen County, IN   8.3   7.4   5.7   4.6   4.2   3.3   3.1
# 3  18005  Bartholomew County, IN   6.3   5.9   4.4   3.6   3.3   2.7   2.6
# 4  18007       Benton County, IN   7.3   6.9   5.4   4.5   4.2   3.4   3.2
#
#    2019  2020  Median Household Income (2019)  NaN  \
# 0   3.2   7.1                         57617.0  NaN
# 1   2.6   5.6                         53532.0  NaN
# 2   3.1   7.7                         56838.0  NaN
# 3   2.4   6.5                         71181.0  NaN
# 4   3.1   5.2                         55016.0  NaN
#
#    % of State Median HH Income
# 0                     1.000000
# 1                     0.929101
# 2                     0.986480
# 3                     1.235417
# 4                     0.954857

# %% [markdown]
# # Write to CSV
# <hr>

# %%
master_df.to_csv('../data/USDA/USDA_unemployment.csv', index=False)

# %%
master_df.shape
# Out:
# (3214, 14)

# %% [markdown]
# <br>

# %% [markdown]
# # EDA

# %%
master_df.shape
# Out:
# (3214, 14)

# %%
master_df.head(2)
# Out:
#    FIPS                    Name  2012  2013  2014  2015  2016  2017  2018  \
# 1  50001     Addison County, VT   4.4   4.1   3.8   3.4   2.9   2.8   2.5
# 2  50003  Bennington County, VT   5.7   5.2   4.7   4.2   3.6   3.7   3.1
#
#    2019  2020  Median Household Income (2019)  % of State Median HH Income  \
# 1   2.3   5.0                         73574.0                     1.162435
# 2   2.9   6.6                         56948.0                     0.899752
#
#      state
# 1  Vermont
# 2  Vermont

# %%
plt.figure(figsize = (17, 17))
sns.scatterplot(data = master_df, x = '2020', y = "Median Household Income (2019)", hue = 'state')

# %%
## Completing Some College
<hr>

# %%
# files managment
path_some_college = "../codeathon/data-overlook/USDA_education/completing_some_college/"
files = os.listdir("path_some_college ")
files.remove(".DS_Store")

# run function 
#
some_college_df, some_college_state_list = concat_csv(path, files)
# rest Index 
some_college_df.reset_index(inplace = True, drop = True)

# %%
completing_college_df.shape

# %%
## Remove rows with all nan's
<hr>

# %%
# identify Nans in FIPS row 
nan_rows_b = some_college_df[some_college_df['FIPS'].isnull()].index
print(len(nan_rows_b))

# %%
# remove rows with all Nans
some_college_df.drop(nan_rows_b, inplace = True)

# %%
## Sanity Check
<hr>

# %%
# checks if there are duplicates in state list
checkIfDuplicates_3(some_college_state_list)

# %%
len(some_college_state_list)

# %%
some_college_df.shape

# %%
some_college_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-189-9a6f1fe716db> in <module>
# ----> 1 some_college_df.head()
#
# NameError: name 'some_college_df' is not defined
