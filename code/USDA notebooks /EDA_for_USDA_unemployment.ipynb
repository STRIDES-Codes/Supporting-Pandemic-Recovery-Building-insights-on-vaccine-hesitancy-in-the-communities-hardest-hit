# %% [markdown]
# # USDA Unemployment
# <hr>

# %%
import pandas as pd
import os

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data
# ## US Unemployment data by county
# Economic Research Service
# U.S. Department of Agriculture
# link:

# %% [markdown]
# ### Notes
#
# - Year 2020, Median Household Income (2019), & '% of State Median HH Income  had 78 Nan Values that are all from Puerto Rico.
# - I am going to drop all rows from Puerto Rico, Puerto Rico does not show up in any of the other USDA data.  If we want it back in, it will be easy to re-add the Puerto Rico data.

# %% [markdown]
# ##  Contants
# <hr>

# %%
stats_master_list = ['Vermont',
 'Mississippi',
 'Maine',
 'Montana',
 'Washington',
 'District of Columbia',
 'Texas',
 'Alabama',
 'Michigan',
 'Maryland',
 'Rhode Island',
 'South Dakota',
 'Nebraska',
 'Virginia',
 'Florida',
 'Utah',
 'Louisiana',
 'Missouri',
 'Massachusetts',
 'South Carolina',
 'Pennsylvania',
 'Tennessee',
 'Minnesota',
 'Idaho',
 'Alaska',
 'Oklahoma',
 'North Dakota',
 'Arkansas',
 'Georgia',
 'New Hampshire',
 'Indiana',
 'Puerto Rico',
 'New Jersey',
 'Delaware',
 'West Virginia',
 'Colorado',
 'New York',
 'Kansas',
 'Arizona',
 'Ohio',
 'Hawaii',
 'Illinois',
 'Oregon',
 'North Carolina',
 'California',
 'Kentucky',
 'Wyoming',
 'Iowa',
 'Nevada',
 'Connecticut',
 'Wisconsin',
 'New Mexico']

# %%
# column Names

columns = [                         'FIPS ',                           'Name',
                                 '2012',                             2013,
                                   2014,                             2015,
                                   2016,                             2017,
                                   2018,                             2019,
                                 '2020', 'Median Household Income (2019)',
          '% of State Median HH Income']

# %%
"""
Duplicate check 3
from 
https://thispointer.com/python-3-ways-to-check-if-there-are-duplicates-in-a-list/
"""
def checkIfDuplicates_3(listOfElems):
    ''' Check if given list contains any duplicates '''    
    for elem in listOfElems:
        if listOfElems.count(elem) > 1:
            return True
    return False

# %% [markdown]
# ## File managment
# <hr>

# %%
files = os.listdir("../data_raw/USDA_gov-unemplyment/")

# %%
# remove mac file 
files.remove('.DS_Store')

# %%
#files

# %% [markdown]
# # Example of the csv files
# <hr>

# %%
# random peek
df = pd.read_excel('../data_raw/USDA_gov-unemplyment/UnemploymentReport (14).xlsx', skiprows=2)

# %%
df.shape
# Out:
# (95, 14)

# %%
df.head()
# Out:
#    FIPS                     Name  2012  2013  2014  2015  2016  2017  2018  \
# 0  18000                 Indiana   8.2   7.5   5.9   4.8   4.4   3.5   3.4
# 1  18001        Adams County, IN   6.9   6.0   4.6   3.8   3.5   2.6   2.6
# 2  18003        Allen County, IN   8.3   7.4   5.7   4.6   4.2   3.3   3.1
# 3  18005  Bartholomew County, IN   6.3   5.9   4.4   3.6   3.3   2.7   2.6
# 4  18007       Benton County, IN   7.3   6.9   5.4   4.5   4.2   3.4   3.2
#
#    2019  2020  Median Household Income (2019)  NaN  \
# 0   3.2   7.1                         57617.0  NaN
# 1   2.6   5.6                         53532.0  NaN
# 2   3.1   7.7                         56838.0  NaN
# 3   2.4   6.5                         71181.0  NaN
# 4   3.1   5.2                         55016.0  NaN
#
#    % of State Median HH Income
# 0                     1.000000
# 1                     0.929101
# 2                     0.986480
# 3                     1.235417
# 4                     0.954857

# %%
df.tail()
# Out:
#                                                 FIPS                 Name  \
# 90                                              18179    Wells County, IN
# 91                                              18181    White County, IN
# 92                                              18183  Whitley County, IN
# 93                                                NaN                 NaN
# 94  Sources: Bureau of Labor Statistics, Local Are...                 NaN
#
#     2012  2013  2014  2015  2016  2017  2018  2019  2020  \
# 90   7.1   6.2   4.8   3.9   3.5   2.9   2.8   2.7   5.7
# 91   7.7   6.7   5.1   4.0   3.9   3.2   3.0   2.6   5.0
# 92   7.8   6.8   5.1   4.1   3.8   2.9   2.8   2.9   5.9
# 93   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 94   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#     Median Household Income (2019)  NaN  % of State Median HH Income
# 90                         61636.0  NaN                     1.069754
# 91                         58295.0  NaN                     1.011767
# 92                         67347.0  NaN                     1.168874
# 93                             NaN  NaN                          NaN
# 94                             NaN  NaN                          NaN

# %% [markdown]
# # Create master DataFrame
# <hr>

# %%
# Concat 

# create master file 
master_df = pd.DataFrame(columns = columns)
state_name_list = []

# LOOP 
for file in files:
    # read excel file
    _df = pd.read_excel('../data_raw/USDA_gov-unemplyment/'+file, skiprows=2)
    # read state_name
    state_name = _df.iloc[0,1]
    

# DROP
    #drop row 0
    _df.drop(0, inplace = True)
    
    # Drop last 2 rows 
    _df.drop(_df.tail(1).index, inplace = True)

    # work around to drop NaN column 
    _temp_df = _df.iloc[:,0:12]
    
    # work around to drop NaN column 
    _temp_df['% of State Median HH Income'] = _df['% of State Median HH Income']
    
# add Column for STATE name
    # add state column 
    _temp_df['state'] = state_name
    state_name_list.append(state_name)
    
    # Concat 
    master_df = pd.concat([master_df, _temp_df])

# %% [markdown]
# <br>

# %% [markdown]
# ## Dataframe clean up
# <hr>

# %%
# reset Index
master_df.reset_index(drop = True, inplace = True )

# %%
master_df.columns
# Out:
# Index([                         'FIPS ',                           'Name',
#                                  '2012',                             2013,
#                                    2014,                             2015,
#                                    2016,                             2017,
#                                    2018,                             2019,
#                                  '2020', 'Median Household Income (2019)',
#           '% of State Median HH Income',                          'state'],
#       dtype='object')

# %%
# Rename columns 
master_df.rename(columns = {'FIPS ':'FIPS'}, inplace = True)

# %%
# shape
master_df.shape
# Out:
# (3269, 14)

# %%
master_df.head()
# Out:
#     FIPS                   Name  2012  2013  2014  2015  2016  2017  2018  \
# 0  50001     Addison County, VT   4.4   4.1   3.8   3.4   2.9   2.8   2.5
# 1  50003  Bennington County, VT   5.7   5.2   4.7   4.2   3.6   3.7   3.1
# 2  50005   Caledonia County, VT   6.1   5.3   4.9   4.6   4.0   3.7   3.2
# 3  50007  Chittenden County, VT   3.7   3.4   3.1   2.7   2.4   2.3   2.0
# 4  50009       Essex County, VT   7.8   6.7   6.0   5.7   4.8   4.7   3.6
#
#    2019  2020  Median Household Income (2019)  % of State Median HH Income  \
# 0   2.3   5.0                         73574.0                     1.162435
# 1   2.9   6.6                         56948.0                     0.899752
# 2   2.9   5.8                         50942.0                     0.804860
# 3   1.7   4.8                         76483.0                     1.208396
# 4   3.1   6.5                         45796.0                     0.723556
#
#      state
# 0  Vermont
# 1  Vermont
# 2  Vermont
# 3  Vermont
# 4  Vermont

# %% [markdown]
# ## Remove rows with all nan's
# <hr>

# %%
master_df.isna().sum()
# Out:
# FIPS                               55
# Name                               55
# 2012                               55
# 2013                               55
# 2014                               55
# 2015                               55
# 2016                               55
# 2017                               55
# 2018                               55
# 2019                               55
# 2020                              133
# Median Household Income (2019)    133
# % of State Median HH Income       133
# state                               0
# dtype: int64

# %%
master_df[ master_df['FIPS'].isnull()].head()
# Out:
#     FIPS Name  2012  2013  2014  2015  2016  2017  2018  2019  2020  \
# 14   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 97   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 114  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 171  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 211  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      Median Household Income (2019)  % of State Median HH Income        state
# 14                              NaN                          NaN      Vermont
# 97                              NaN                          NaN  Mississippi
# 114                             NaN                          NaN        Maine
# 171                             NaN                          NaN      Montana
# 211                             NaN                          NaN   Washington

# %%
nan_rows = master_df[ master_df['FIPS'].isnull()].index
nan_rows
# Out:
# Int64Index([  14,   97,  114,  171,  211,  213,  468,  469,  537,  621,  646,
#              652,  718,  812,  946,  947, 1015, 1045, 1110, 1226, 1241, 1288,
#             1356, 1452, 1540, 1585, 1611, 1689, 1743, 1819, 1979, 1980, 1991,
#             2084, 2163, 2185, 2189, 2245, 2310, 2373, 2479, 2495, 2584, 2589,
#             2692, 2729, 2830, 2889, 3010, 3034, 3134, 3152, 3161, 3234, 3268],
#            dtype='int64')

# %%
len(nan_rows)
# Out:
# 55

# %%
# remove rows with all Nans
master_df.drop(nan_rows, inplace = True)

# %%
master_df.isna().sum()
# Out:
# FIPS                               0
# Name                               0
# 2012                               0
# 2013                               0
# 2014                               0
# 2015                               0
# 2016                               0
# 2017                               0
# 2018                               0
# 2019                               0
# 2020                              78
# Median Household Income (2019)    78
# % of State Median HH Income       78
# state                              0
# dtype: int64

# %%
master_df[ master_df['2020'].isnull()].iloc[20:25,:]
# Out:
#        FIPS                   Name  2012  2013  2014  2015  2016  2017  2018  \
# 2105  72041    Cidra Municipio, PR  14.5  12.7  12.0   9.9  10.2   8.4   7.6
# 2106  72043    Coamo Municipio, PR  21.0  20.2  21.0  18.9  18.1  16.2  13.9
# 2107  72045  Comerio Municipio, PR  20.4  20.0  18.8  15.2  13.5  11.8  10.3
# 2108  72047  Corozal Municipio, PR  16.0  15.0  15.1  13.5  12.3  11.3   9.4
# 2109  72049  Culebra Municipio, PR   5.7   6.7   6.2   3.7   3.3   4.4   4.4
#
#       2019  2020  Median Household Income (2019)  % of State Median HH Income  \
# 2105   6.8   NaN                             NaN                          NaN
# 2106  12.3   NaN                             NaN                          NaN
# 2107   8.9   NaN                             NaN                          NaN
# 2108   9.1   NaN                             NaN                          NaN
# 2109   3.1   NaN                             NaN                          NaN
#
#             state
# 2105  Puerto Rico
# 2106  Puerto Rico
# 2107  Puerto Rico
# 2108  Puerto Rico
# 2109  Puerto Rico

# %% [markdown]
# - There are 78 rows that do have nans for 2020,
# - all of the Remaing rows with nan's are form Puerto Rico
#
# - I am going to remove the Nans from Puerto Rico because the other USDA data sets do not have Puerto Rico

# %%
master_df[ master_df['state'] == 'Puerto Rico' ].index
# Out:
# Int64Index([2085, 2086, 2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095,
#             2096, 2097, 2098, 2099, 2100, 2101, 2102, 2103, 2104, 2105, 2106,
#             2107, 2108, 2109, 2110, 2111, 2112, 2113, 2114, 2115, 2116, 2117,
#             2118, 2119, 2120, 2121, 2122, 2123, 2124, 2125, 2126, 2127, 2128,
#             2129, 2130, 2131, 2132, 2133, 2134, 2135, 2136, 2137, 2138, 2139,
#             2140, 2141, 2142, 2143, 2144, 2145, 2146, 2147, 2148, 2149, 2150,
#             2151, 2152, 2153, 2154, 2155, 2156, 2157, 2158, 2159, 2160, 2161,
#             2162],
#            dtype='int64')

# %%
# Drop all Rows with state as Puerto Rico

index_names = master_df[ master_df['state'] == 'Puerto Rico' ].index
master_df.drop(index_names, inplace = True)

# %%
master_df.drop([], inplace = True  )

# %%
master_df.isna().sum()
# Out:
# FIPS                              0
# Name                              0
# 2012                              0
# 2013                              0
# 2014                              0
# 2015                              0
# 2016                              0
# 2017                              0
# 2018                              0
# 2019                              0
# 2020                              0
# Median Household Income (2019)    0
# % of State Median HH Income       0
# state                             0
# dtype: int64

# %%
master_df.shape
# Out:
# (3136, 14)

# %% [markdown]
# <br>

# %% [markdown]
# # Sanity Check
# <hr>

# %%
# unique Count of stats

# %%
master_df['state'].nunique()
# Out:
# 51

# %%
len(state_name_list)
# Out:
# 52

# %%
# checks if there are duplicates in state list
checkIfDuplicates_3(state_name_list)
# Out:
# False

# %%
master_df['state'].nunique()
# Out:
# 51

# %% [markdown]
# # Write to CSV
# <hr>

# %%
master_df.to_csv('../data/USDA/USDA_unemployment.csv', index=False)

# %%
master_df.shape
# Out:
# (3136, 14)

# %% [markdown]
# <br>

# %% [markdown]
# # EDA

# %%
master_df.shape
# Out:
# (3136, 14)

# %%
master_df.head(2)
# Out:
#     FIPS                   Name  2012  2013  2014  2015  2016  2017  2018  \
# 0  50001     Addison County, VT   4.4   4.1   3.8   3.4   2.9   2.8   2.5
# 1  50003  Bennington County, VT   5.7   5.2   4.7   4.2   3.6   3.7   3.1
#
#    2019  2020  Median Household Income (2019)  % of State Median HH Income  \
# 0   2.3   5.0                         73574.0                     1.162435
# 1   2.9   6.6                         56948.0                     0.899752
#
#      state
# 0  Vermont
# 1  Vermont

# %%
plt.figure(figsize = (17, 17))
sns.scatterplot(data = master_df, x = '2020', y = "Median Household Income (2019)", hue = 'state');

plt.xlabel("% of unemployment")
plt.title("% of Unemployment by Household Median income 2019")
# Out:
# Text(0.5, 1.0, '% of Unemployment by Household Median income 2019')

# %%
set(master_df['FIPS'])
# Out:
# {'20135',
#  '20051',
#  '48417',
#  '17025',
#  '41019',
#  '48183',
#  '51125',
#  '13141',
#  '26069',
#  '36013',
#  '21157',
#  '50017',
#  '06091',
#  '27045',
#  '38083',
#  '55097',
#  '17065',
#  '48211',
#  '13251',
#  '56039',
#  '22009',
#  '04007',
#  '06107',
#  '18161',
#  '10001',
#  '38097',
#  '13321',
#  '29101',
#  '27087',
#  '04019',
#  '12121',
#  '29043',
#  '48487',
#  '13257',
#  '31029',
#  '13301',
#  '21169',
#  '47089',
#  '29203',
#  '13035',
#  '08065',
#  '02110',
#  '22017',
#  '42041',
#  '16025',
#  '31153',
#  '20057',
#  '31145',
#  '13057',
#  '18109',
#  '20037',
#  '30033',
#  '48327',
#  '48433',
#  '17063',
#  '48135',
#  '26075',
#  '42049',
#  '40103',
#  '19073',
#  '13039',
#  '08121',
#  '20089',
#  '50025',
#  '48263',
#  '21195',
#  '54007',
#  '51083',
#  '17187',
#  '37185',
#  '22105',
#  '48173',
#  '45047',
#  '27037',
#  '12075',
#  '13277',
#  '48305',
#  '12086',
#  '27059',
#  '46059',
#  '22033',
#  '18059',
#  '51775',
#  '40099',
#  '51550',
#  '13015',
#  '19191',
#  '30009',
#  '42107',
#  '48309',
